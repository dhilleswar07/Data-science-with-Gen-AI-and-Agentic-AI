# %%
#!pip install --upgrade langchain
#!pip install langchain_community
#!pip install langchain_text_splitter
#!pip install langchain_chroma
#!pip install langchain_groq
#!pip install langchain
# Out:
# Requirement already satisfied: langchain in /usr/local/lib/python3.13/dist-packages (1.4.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.6.3 in /usr/local/lib/python3.13/dist-packages (from langchain) (1.6.3)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.11 in /usr/local/lib/python3.13/dist-packages (from langchain) (1.2.11)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.13/dist-packages (from langchain) (2.13.5)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.3->langchain) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.3->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.3->langchain) (0.0.19)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.3->langchain) (0.12.1)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.3->langchain) (26.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.3->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.3->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.3->langchain) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.3->langchain) (0.17.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in /usr/local/lib/python3.13/dist-packages (from langgraph<1.3.0,>=1.2.11->langchain) (4.2.0)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from langgraph<1.3.0,>=1.2.11->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from langgraph<1.3.0,>=1.2.11->langchain) (0.4.4)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.13/dist-packages (from langgraph<1.3.0,>=1.2.11->langchain) (4.0.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.3->langchain) (4.14.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.3->langchain) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.3->langchain) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.3->langchain) (3.19)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.3->langchain) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.13/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.6.3->langchain) (3.1.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in /usr/local/lib/python3.13/dist-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.11->langchain) (1.12.2)
# Requirement already satisfied: orjson>=3.11.5 in /usr/local/lib/python3.13/dist-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (3.12.0)
# Requirement already satisfied: websockets<17,>=14 in /usr/local/lib/python3.13/dist-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (15.0.1)
# Requirement already satisfied: distro>=1.7.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.3->langchain) (1.9.0)
# Requirement already satisfied: httpx2<3,>=2 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.3->langchain) (2.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.3->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.3->langchain) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.3->langchain) (1.3.1)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.3->langchain) (0.25.0)
# Requirement already satisfied: httpcore2==2.12.0 in /usr/local/lib/python3.13/dist-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.3->langchain) (2.12.0)
# Requirement already satisfied: truststore>=0.10 in /usr/local/lib/python3.13/dist-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.3->langchain) (0.10.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.3->langchain) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.13/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.3->langchain) (2.5.0)
# Requirement already satisfied: langchain_community in /usr/local/lib/python3.13/dist-packages (0.4.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.13/dist-packages (from langchain_community) (3.14.3)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.13/dist-packages (from langchain_community) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in /usr/local/lib/python3.13/dist-packages (from langchain_community) (1.0.8)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from langchain_community) (1.6.3)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /usr/local/lib/python3.13/dist-packages (from langchain_community) (0.12.1)
# Requirement already satisfied: numpy>=2.1.0 in /usr/local/lib/python3.13/dist-packages (from langchain_community) (2.1.3)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /usr/local/lib/python3.13/dist-packages (from langchain_community) (2.15.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.13/dist-packages (from langchain_community) (6.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in /usr/local/lib/python3.13/dist-packages (from langchain_community) (2.34.2)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from langchain_community) (2.0.52)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.13/dist-packages (from langchain_community) (9.1.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.24.5)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in /usr/local/lib/python3.13/dist-packages (from langchain-classic<2.0.0,>=1.0.7->langchain_community) (1.1.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.13/dist-packages (from langchain-classic<2.0.0,>=1.0.7->langchain_community) (2.13.5)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain_community) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain_community) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain_community) (0.0.19)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain_community) (26.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain_community) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain_community) (0.17.0)
# Requirement already satisfied: anyio>=3.5.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (4.14.2)
# Requirement already satisfied: distro>=1.7.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (1.9.0)
# Requirement already satisfied: httpx2<3,>=2 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (2.12.0)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (3.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (4.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.25.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.13/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (1.2.3)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.13/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (0.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.19)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.32.5->langchain_community) (2.5.0)
# Requirement already satisfied: certifi>=2023.5.7 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.32.5->langchain_community) (2026.7.22)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.13/dist-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain_community) (3.5.5)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.4.0->langchain_community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.4.0->langchain_community) (0.16.0)
# Requirement already satisfied: httpcore2==2.12.0 in /usr/local/lib/python3.13/dist-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.1.125->langchain_community) (2.12.0)
# Requirement already satisfied: truststore>=0.10 in /usr/local/lib/python3.13/dist-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.1.125->langchain_community) (0.10.4)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.13/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain_community) (3.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain_community) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.7->langchain_community) (2.46.5)
# ERROR: Could not find a version that satisfies the requirement langchain_text_splitter (from versions: none)
# ERROR: No matching distribution found for langchain_text_splitter
# Requirement already satisfied: langchain_chroma in /usr/local/lib/python3.13/dist-packages (1.1.0)
# Requirement already satisfied: chromadb<2.0.0,>=1.3.5 in /usr/local/lib/python3.13/dist-packages (from langchain_chroma) (1.5.9)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.3 in /usr/local/lib/python3.13/dist-packages (from langchain_chroma) (1.6.3)
# Requirement already satisfied: numpy>=2.1.0 in /usr/local/lib/python3.13/dist-packages (from langchain_chroma) (2.1.3)
# Requirement already satisfied: build>=1.0.3 in /usr/local/lib/python3.13/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain_chroma) (1.6.1)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.13/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain_chroma) (2.13.5)
# Requirement already satisfied: pydantic-settings>=2.0 in /usr/local/lib/python3.13/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain_chroma) (2.15.0)
# Requirement already satisfied: pybase64>=1.4.1 in /usr/local/lib/python3.13/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain_chroma) (1.5.0)
# Requirement already satisfied: uvicorn>=0.18.3 in /usr/local/lib/python3.13/dist-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain_chroma) (0.52.4)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.13/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain_chroma) (4.16.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /usr/local/lib/python3.13/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain_chroma) (1.30.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain_chroma) (1.44.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain_chroma) (1.44.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain_chroma) (1.44.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.13/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain_chroma) (0.23.1)
# Requirement already satisfied: pypika>=0.48.9 in /usr/local/lib/python3.13/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain_chroma) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.13/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain_chroma) (4.67.3)
# Requirement already satisfied: overrides>=7.3.1 in /usr/local/lib/python3.13/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain_chroma) (7.7.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.13/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain_chroma) (7.1.0)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.13/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain_chroma) (1.83.1)
# Requirement already satisfied: bcrypt>=4.0.1 in /usr/local/lib/python3.13/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain_chroma) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.13/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain_chroma) (0.27.2)
# Requirement already satisfied: kubernetes>=28.1.0 in /usr/local/lib/python3.13/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain_chroma) (36.0.3)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.13/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain_chroma) (9.1.4)
# Requirement already satisfied: pyyaml>=6.0.0 in /usr/local/lib/python3.13/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain_chroma) (6.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in /usr/local/lib/python3.13/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain_chroma) (5.3.0)
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.13/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain_chroma) (3.12.0)
# Requirement already satisfied: httpx>=0.27.0 in /usr/local/lib/python3.13/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain_chroma) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.13/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain_chroma) (13.9.4)
# Requirement already satisfied: jsonschema>=4.19.0 in /usr/local/lib/python3.13/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain_chroma) (4.26.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.1.3->langchain_chroma) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.1.3->langchain_chroma) (0.0.19)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.1.3->langchain_chroma) (0.12.1)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.1.3->langchain_chroma) (26.3)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.1.3->langchain_chroma) (0.17.0)
# Requirement already satisfied: pyproject_hooks in /usr/local/lib/python3.13/dist-packages (from build>=1.0.3->chromadb<2.0.0,>=1.3.5->langchain_chroma) (1.3.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.13/dist-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (4.14.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.13/dist-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (3.19)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.13/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.3->langchain_chroma) (3.1.1)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (2026.6.3)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.13/dist-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.13/dist-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.13/dist-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (1.9.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.13/dist-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (2.34.2)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.13/dist-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (2.0.0)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in /usr/local/lib/python3.13/dist-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (2.5.0)
# Requirement already satisfied: durationpy>=0.7 in /usr/local/lib/python3.13/dist-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (0.11)
# Requirement already satisfied: aiohttp<4.0.0,>=3.13.5 in /usr/local/lib/python3.13/dist-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (3.14.3)
# Requirement already satisfied: distro>=1.7.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain_chroma) (1.9.0)
# Requirement already satisfied: httpx2<3,>=2 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain_chroma) (2.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain_chroma) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain_chroma) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain_chroma) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain_chroma) (4.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain_chroma) (0.25.0)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.13/dist-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain_chroma) (25.12.19)
# Requirement already satisfied: protobuf>=4.25.8 in /usr/local/lib/python3.13/dist-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain_chroma) (5.29.6)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /usr/local/lib/python3.13/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (1.75.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.44.0 in /usr/local/lib/python3.13/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (1.44.0)
# Requirement already satisfied: opentelemetry-proto==1.44.0 in /usr/local/lib/python3.13/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (1.44.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.65b0 in /usr/local/lib/python3.13/dist-packages (from opentelemetry-sdk>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (0.65b0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic>=2.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in /usr/local/lib/python3.13/dist-packages (from pydantic>=2.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic>=2.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (0.4.4)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.13/dist-packages (from pydantic-settings>=2.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (1.2.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.13/dist-packages (from rich>=10.11.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.13/dist-packages (from rich>=10.11.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (2.21.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /usr/local/lib/python3.13/dist-packages (from tokenizers>=0.13.2->chromadb<2.0.0,>=1.3.5->langchain_chroma) (1.29.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.13/dist-packages (from typer>=0.9.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.13/dist-packages (from typer>=0.9.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (0.0.5)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.13/dist-packages (from uvicorn>=0.18.3->uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain_chroma) (8.5.0)
# Requirement already satisfied: httptools>=0.8.0 in /usr/local/lib/python3.13/dist-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain_chroma) (0.8.0)
# Requirement already satisfied: uvloop>=0.15.1 in /usr/local/lib/python3.13/dist-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain_chroma) (0.22.1)
# Requirement already satisfied: watchfiles>=0.20 in /usr/local/lib/python3.13/dist-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain_chroma) (1.2.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (1.24.5)
# Requirement already satisfied: httpcore2==2.12.0 in /usr/local/lib/python3.13/dist-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain_chroma) (2.12.0)
# Requirement already satisfied: truststore>=0.10 in /usr/local/lib/python3.13/dist-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain_chroma) (0.10.4)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.3.5->langchain_chroma) (3.32.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.3.5->langchain_chroma) (2025.12.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.2 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.3.5->langchain_chroma) (1.6.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.13/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (0.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (3.4.9)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.13/dist-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (3.3.1)
# Requirement already satisfied: langchain_groq in /usr/local/lib/python3.13/dist-packages (1.1.3)
# Requirement already satisfied: groq<1.0.0,>=0.30.0 in /usr/local/lib/python3.13/dist-packages (from langchain_groq) (0.37.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from langchain_groq) (1.6.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.13/dist-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (4.14.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.13/dist-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.13/dist-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (2.13.5)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.13/dist-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.13/dist-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (4.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain_groq) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain_groq) (0.0.19)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain_groq) (0.12.1)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain_groq) (26.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain_groq) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain_groq) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain_groq) (0.17.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.13/dist-packages (from anyio<5,>=3.5.0->groq<1.0.0,>=0.30.0->langchain_groq) (3.19)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain_groq) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain_groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain_groq) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.13/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain_groq) (3.1.1)
# Requirement already satisfied: httpx2<3,>=2 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain_groq) (2.12.0)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain_groq) (3.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain_groq) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain_groq) (2.34.2)
# Requirement already satisfied: websockets>=15.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain_groq) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain_groq) (4.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain_groq) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain_groq) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in /usr/local/lib/python3.13/dist-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain_groq) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain_groq) (0.4.4)
# Requirement already satisfied: httpcore2==2.12.0 in /usr/local/lib/python3.13/dist-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain_groq) (2.12.0)
# Requirement already satisfied: truststore>=0.10 in /usr/local/lib/python3.13/dist-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain_groq) (0.10.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain_groq) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.13/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain_groq) (2.5.0)
# Requirement already satisfied: langchain in /usr/local/lib/python3.13/dist-packages (1.4.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.6.3 in /usr/local/lib/python3.13/dist-packages (from langchain) (1.6.3)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.11 in /usr/local/lib/python3.13/dist-packages (from langchain) (1.2.11)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.13/dist-packages (from langchain) (2.13.5)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.3->langchain) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.3->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.3->langchain) (0.0.19)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.3->langchain) (0.12.1)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.3->langchain) (26.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.3->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.3->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.3->langchain) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.3->langchain) (0.17.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in /usr/local/lib/python3.13/dist-packages (from langgraph<1.3.0,>=1.2.11->langchain) (4.2.0)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from langgraph<1.3.0,>=1.2.11->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from langgraph<1.3.0,>=1.2.11->langchain) (0.4.4)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.13/dist-packages (from langgraph<1.3.0,>=1.2.11->langchain) (4.0.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.3->langchain) (4.14.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.3->langchain) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.3->langchain) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.3->langchain) (3.19)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.3->langchain) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.13/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.6.3->langchain) (3.1.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in /usr/local/lib/python3.13/dist-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.11->langchain) (1.12.2)
# Requirement already satisfied: orjson>=3.11.5 in /usr/local/lib/python3.13/dist-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (3.12.0)
# Requirement already satisfied: websockets<17,>=14 in /usr/local/lib/python3.13/dist-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (15.0.1)
# Requirement already satisfied: distro>=1.7.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.3->langchain) (1.9.0)
# Requirement already satisfied: httpx2<3,>=2 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.3->langchain) (2.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.3->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.3->langchain) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.3->langchain) (1.3.1)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.3->langchain) (0.25.0)
# Requirement already satisfied: httpcore2==2.12.0 in /usr/local/lib/python3.13/dist-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.3->langchain) (2.12.0)
# Requirement already satisfied: truststore>=0.10 in /usr/local/lib/python3.13/dist-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.3->langchain) (0.10.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.3->langchain) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.13/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.3->langchain) (2.5.0)

# %%
import os
#from langchain.document_loaders import UnstructuredFileLoader #old import not working
from langchain_community.document_loaders import UnstructuredFileLoader
from langchain_text_splitters import CharacterTextSplitter
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_chroma import Chroma
from langchain_groq import ChatGroq
from langchain_classic.chains import RetrievalQA
# Out:
# /tmp/ipykernel_8673/1170151002.py:3: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import UnstructuredFileLoader

# %%
os.environ["GROQ_API_KEY"]= "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"

# %%
import requests
url = "https://dspmuranchi.ac.in/pdf/Blog/Python%20Built-In%20Functions.pdf"
response = requests.get(url)

# %%
#save pdf to a local file
with open ("python_built_in_functions.pdf", "wb") as f:
    f.write(response.content)

# %%
#!pip install unstructured
# Out:
# Requirement already satisfied: unstructured in /usr/local/lib/python3.13/dist-packages (0.27.6)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.14.3 in /usr/local/lib/python3.13/dist-packages (from unstructured) (4.15.0)
# Requirement already satisfied: charset-normalizer<4.0.0,>=3.4.4 in /usr/local/lib/python3.13/dist-packages (from unstructured) (3.4.9)
# Requirement already satisfied: emoji<3.0.0,>=2.15.0 in /usr/local/lib/python3.13/dist-packages (from unstructured) (2.16.0)
# Requirement already satisfied: filelock<4.0.0,>=3.12.0 in /usr/local/lib/python3.13/dist-packages (from unstructured) (3.32.5)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from unstructured) (1.2.0)
# Requirement already satisfied: html5lib<2.0.0,>=1.1 in /usr/local/lib/python3.13/dist-packages (from unstructured) (1.1)
# Requirement already satisfied: installer<1.0.0,>=0.7.0 in /usr/local/lib/python3.13/dist-packages (from unstructured) (0.7.0)
# Requirement already satisfied: langdetect<2.0.0,>=1.0.9 in /usr/local/lib/python3.13/dist-packages (from unstructured) (1.0.9)
# Requirement already satisfied: lxml<7.0.0,>=5.0.0 in /usr/local/lib/python3.13/dist-packages (from unstructured) (6.1.2)
# Requirement already satisfied: nh3<1.0.0,>=0.3.0 in /usr/local/lib/python3.13/dist-packages (from unstructured) (0.3.7)
# Requirement already satisfied: numba<1.0.0,>=0.60.0 in /usr/local/lib/python3.13/dist-packages (from unstructured) (0.61.2)
# Requirement already satisfied: numpy<3.0.0,>=1.26.0 in /usr/local/lib/python3.13/dist-packages (from unstructured) (2.1.3)
# Requirement already satisfied: psutil<8.0.0,>=7.2.2 in /usr/local/lib/python3.13/dist-packages (from unstructured) (7.2.2)
# Requirement already satisfied: python-iso639<2027.0.0,>=2026.1.31 in /usr/local/lib/python3.13/dist-packages (from unstructured) (2026.7.23)
# Requirement already satisfied: python-magic<1.0.0,>=0.4.27 in /usr/local/lib/python3.13/dist-packages (from unstructured) (0.4.27)
# Requirement already satisfied: python-oxmsg<1.0.0,>=0.0.2 in /usr/local/lib/python3.13/dist-packages (from unstructured) (0.0.2)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.14.3 in /usr/local/lib/python3.13/dist-packages (from unstructured) (3.14.6)
# Requirement already satisfied: regex<2027.0.0,>=2024.0.0 in /usr/local/lib/python3.13/dist-packages (from unstructured) (2025.11.3)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in /usr/local/lib/python3.13/dist-packages (from unstructured) (2.34.2)
# Requirement already satisfied: spacy<4.0.0,>=3.7.0 in /usr/local/lib/python3.13/dist-packages (from unstructured) (3.8.16)
# Requirement already satisfied: tqdm<5.0.0,>=4.67.3 in /usr/local/lib/python3.13/dist-packages (from unstructured) (4.67.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.15.0 in /usr/local/lib/python3.13/dist-packages (from unstructured) (4.16.0)
# Requirement already satisfied: unstructured-client<1.0.0,>=0.25.9 in /usr/local/lib/python3.13/dist-packages (from unstructured) (0.46.2)
# Requirement already satisfied: wrapt<3.0.0,>=2.1.1 in /usr/local/lib/python3.13/dist-packages (from unstructured) (2.4.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /usr/local/lib/python3.13/dist-packages (from beautifulsoup4<5.0.0,>=4.14.3->unstructured) (2.9.2)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.13/dist-packages (from html5lib<2.0.0,>=1.1->unstructured) (1.17.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.13/dist-packages (from html5lib<2.0.0,>=1.1->unstructured) (0.6.1)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /usr/local/lib/python3.13/dist-packages (from numba<1.0.0,>=0.60.0->unstructured) (0.44.0)
# Requirement already satisfied: click in /usr/local/lib/python3.13/dist-packages (from python-oxmsg<1.0.0,>=0.0.2->unstructured) (8.5.0)
# Requirement already satisfied: olefile in /usr/local/lib/python3.13/dist-packages (from python-oxmsg<1.0.0,>=0.0.2->unstructured) (0.47)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.32.5->unstructured) (3.19)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.32.5->unstructured) (2.5.0)
# Requirement already satisfied: certifi>=2023.5.7 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.32.5->unstructured) (2026.7.22)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (1.3.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (0.27.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (2.13.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (80.10.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (26.3)
# Requirement already satisfied: aiofiles>=25.1.0 in /usr/local/lib/python3.13/dist-packages (from unstructured-client<1.0.0,>=0.25.9->unstructured) (25.1.0)
# Requirement already satisfied: httpcore>=1.0.9 in /usr/local/lib/python3.13/dist-packages (from unstructured-client<1.0.0,>=0.25.9->unstructured) (1.0.9)
# Requirement already satisfied: httpx>=0.28.1 in /usr/local/lib/python3.13/dist-packages (from unstructured-client<1.0.0,>=0.25.9->unstructured) (0.28.1)
# Requirement already satisfied: pypdf>=6.9.2 in /usr/local/lib/python3.13/dist-packages (from unstructured-client<1.0.0,>=0.25.9->unstructured) (6.19.0)
# Requirement already satisfied: pypdfium2>=5.6.0 in /usr/local/lib/python3.13/dist-packages (from unstructured-client<1.0.0,>=0.25.9->unstructured) (5.13.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from unstructured-client<1.0.0,>=0.25.9->unstructured) (1.0.0)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore>=1.0.9->unstructured-client<1.0.0,>=0.25.9->unstructured) (0.16.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.13/dist-packages (from httpx>=0.28.1->unstructured-client<1.0.0,>=0.25.9->unstructured) (4.14.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.0.0->spacy<4.0.0,>=3.7.0->unstructured) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.0.0->spacy<4.0.0,>=3.7.0->unstructured) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.0.0->spacy<4.0.0,>=3.7.0->unstructured) (0.4.4)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.13/dist-packages (from thinc<8.4.0,>=8.3.12->spacy<4.0.0,>=3.7.0->unstructured) (1.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.13/dist-packages (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.13/dist-packages (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.13/dist-packages (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured) (0.0.5)
# Requirement already satisfied: cloudpathlib>=0.7.0 in /usr/local/lib/python3.13/dist-packages (from weasel<2.0.0,>=1.0.0->spacy<4.0.0,>=3.7.0->unstructured) (0.25.0)
# Requirement already satisfied: smart-open>=5.2.1 in /usr/local/lib/python3.13/dist-packages (from weasel<2.0.0,>=1.0.0->spacy<4.0.0,>=3.7.0->unstructured) (8.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->spacy<4.0.0,>=3.7.0->unstructured) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.13/dist-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.13/dist-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured) (2.21.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.13/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured) (0.1.2)

# %%
#loading the document
loader = UnstructuredFileLoader("python_built_in_functions.pdf")
# Out:
# /tmp/ipykernel_8673/2304352052.py:2: LangChainDeprecationWarning: The class `UnstructuredFileLoader` was deprecated in LangChain 0.2.8 and will be removed in 1.0. An updated version of the class exists in the `langchain-unstructured package and should be used instead. To use it run `pip install -U `langchain-unstructured` and import as `from `langchain_unstructured import UnstructuredLoader``.
#   loader = UnstructuredFileLoader("python_built_in_functions.pdf")

# %%
# !pip install unstructured
# Out:
# Requirement already satisfied: unstructured in /usr/local/lib/python3.13/dist-packages (0.27.6)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.14.3 in /usr/local/lib/python3.13/dist-packages (from unstructured) (4.15.0)
# Requirement already satisfied: charset-normalizer<4.0.0,>=3.4.4 in /usr/local/lib/python3.13/dist-packages (from unstructured) (3.4.9)
# Requirement already satisfied: emoji<3.0.0,>=2.15.0 in /usr/local/lib/python3.13/dist-packages (from unstructured) (2.16.0)
# Requirement already satisfied: filelock<4.0.0,>=3.12.0 in /usr/local/lib/python3.13/dist-packages (from unstructured) (3.32.5)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from unstructured) (1.2.0)
# Requirement already satisfied: html5lib<2.0.0,>=1.1 in /usr/local/lib/python3.13/dist-packages (from unstructured) (1.1)
# Requirement already satisfied: installer<1.0.0,>=0.7.0 in /usr/local/lib/python3.13/dist-packages (from unstructured) (0.7.0)
# Requirement already satisfied: langdetect<2.0.0,>=1.0.9 in /usr/local/lib/python3.13/dist-packages (from unstructured) (1.0.9)
# Requirement already satisfied: lxml<7.0.0,>=5.0.0 in /usr/local/lib/python3.13/dist-packages (from unstructured) (6.1.2)
# Requirement already satisfied: nh3<1.0.0,>=0.3.0 in /usr/local/lib/python3.13/dist-packages (from unstructured) (0.3.7)
# Requirement already satisfied: numba<1.0.0,>=0.60.0 in /usr/local/lib/python3.13/dist-packages (from unstructured) (0.61.2)
# Requirement already satisfied: numpy<3.0.0,>=1.26.0 in /usr/local/lib/python3.13/dist-packages (from unstructured) (2.1.3)
# Requirement already satisfied: psutil<8.0.0,>=7.2.2 in /usr/local/lib/python3.13/dist-packages (from unstructured) (7.2.2)
# Requirement already satisfied: python-iso639<2027.0.0,>=2026.1.31 in /usr/local/lib/python3.13/dist-packages (from unstructured) (2026.7.23)
# Requirement already satisfied: python-magic<1.0.0,>=0.4.27 in /usr/local/lib/python3.13/dist-packages (from unstructured) (0.4.27)
# Requirement already satisfied: python-oxmsg<1.0.0,>=0.0.2 in /usr/local/lib/python3.13/dist-packages (from unstructured) (0.0.2)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.14.3 in /usr/local/lib/python3.13/dist-packages (from unstructured) (3.14.6)
# Requirement already satisfied: regex<2027.0.0,>=2024.0.0 in /usr/local/lib/python3.13/dist-packages (from unstructured) (2025.11.3)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in /usr/local/lib/python3.13/dist-packages (from unstructured) (2.34.2)
# Requirement already satisfied: spacy<4.0.0,>=3.7.0 in /usr/local/lib/python3.13/dist-packages (from unstructured) (3.8.16)
# Requirement already satisfied: tqdm<5.0.0,>=4.67.3 in /usr/local/lib/python3.13/dist-packages (from unstructured) (4.67.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.15.0 in /usr/local/lib/python3.13/dist-packages (from unstructured) (4.16.0)
# Requirement already satisfied: unstructured-client<1.0.0,>=0.25.9 in /usr/local/lib/python3.13/dist-packages (from unstructured) (0.46.2)
# Requirement already satisfied: wrapt<3.0.0,>=2.1.1 in /usr/local/lib/python3.13/dist-packages (from unstructured) (2.4.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /usr/local/lib/python3.13/dist-packages (from beautifulsoup4<5.0.0,>=4.14.3->unstructured) (2.9.2)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.13/dist-packages (from html5lib<2.0.0,>=1.1->unstructured) (1.17.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.13/dist-packages (from html5lib<2.0.0,>=1.1->unstructured) (0.6.1)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /usr/local/lib/python3.13/dist-packages (from numba<1.0.0,>=0.60.0->unstructured) (0.44.0)
# Requirement already satisfied: click in /usr/local/lib/python3.13/dist-packages (from python-oxmsg<1.0.0,>=0.0.2->unstructured) (8.5.0)
# Requirement already satisfied: olefile in /usr/local/lib/python3.13/dist-packages (from python-oxmsg<1.0.0,>=0.0.2->unstructured) (0.47)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.32.5->unstructured) (3.19)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.32.5->unstructured) (2.5.0)
# Requirement already satisfied: certifi>=2023.5.7 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.32.5->unstructured) (2026.7.22)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (1.3.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (0.27.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (2.13.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (80.10.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured) (26.3)
# Requirement already satisfied: aiofiles>=25.1.0 in /usr/local/lib/python3.13/dist-packages (from unstructured-client<1.0.0,>=0.25.9->unstructured) (25.1.0)
# Requirement already satisfied: httpcore>=1.0.9 in /usr/local/lib/python3.13/dist-packages (from unstructured-client<1.0.0,>=0.25.9->unstructured) (1.0.9)
# Requirement already satisfied: httpx>=0.28.1 in /usr/local/lib/python3.13/dist-packages (from unstructured-client<1.0.0,>=0.25.9->unstructured) (0.28.1)
# Requirement already satisfied: pypdf>=6.9.2 in /usr/local/lib/python3.13/dist-packages (from unstructured-client<1.0.0,>=0.25.9->unstructured) (6.19.0)
# Requirement already satisfied: pypdfium2>=5.6.0 in /usr/local/lib/python3.13/dist-packages (from unstructured-client<1.0.0,>=0.25.9->unstructured) (5.13.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from unstructured-client<1.0.0,>=0.25.9->unstructured) (1.0.0)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore>=1.0.9->unstructured-client<1.0.0,>=0.25.9->unstructured) (0.16.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.13/dist-packages (from httpx>=0.28.1->unstructured-client<1.0.0,>=0.25.9->unstructured) (4.14.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.0.0->spacy<4.0.0,>=3.7.0->unstructured) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.0.0->spacy<4.0.0,>=3.7.0->unstructured) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.0.0->spacy<4.0.0,>=3.7.0->unstructured) (0.4.4)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.13/dist-packages (from thinc<8.4.0,>=8.3.12->spacy<4.0.0,>=3.7.0->unstructured) (1.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.13/dist-packages (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.13/dist-packages (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.13/dist-packages (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured) (0.0.5)
# Requirement already satisfied: cloudpathlib>=0.7.0 in /usr/local/lib/python3.13/dist-packages (from weasel<2.0.0,>=1.0.0->spacy<4.0.0,>=3.7.0->unstructured) (0.25.0)
# Requirement already satisfied: smart-open>=5.2.1 in /usr/local/lib/python3.13/dist-packages (from weasel<2.0.0,>=1.0.0->spacy<4.0.0,>=3.7.0->unstructured) (8.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->spacy<4.0.0,>=3.7.0->unstructured) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.13/dist-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.13/dist-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured) (2.21.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.13/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured) (0.1.2)

# %%
loader

# %%
# !pip install "unstructured[pdf]"
# Out:
# Requirement already satisfied: unstructured[pdf] in /usr/local/lib/python3.13/dist-packages (0.27.6)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.14.3 in /usr/local/lib/python3.13/dist-packages (from unstructured[pdf]) (4.15.0)
# Requirement already satisfied: charset-normalizer<4.0.0,>=3.4.4 in /usr/local/lib/python3.13/dist-packages (from unstructured[pdf]) (3.4.9)
# Requirement already satisfied: emoji<3.0.0,>=2.15.0 in /usr/local/lib/python3.13/dist-packages (from unstructured[pdf]) (2.16.0)
# Requirement already satisfied: filelock<4.0.0,>=3.12.0 in /usr/local/lib/python3.13/dist-packages (from unstructured[pdf]) (3.32.5)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from unstructured[pdf]) (1.2.0)
# Requirement already satisfied: html5lib<2.0.0,>=1.1 in /usr/local/lib/python3.13/dist-packages (from unstructured[pdf]) (1.1)
# Requirement already satisfied: installer<1.0.0,>=0.7.0 in /usr/local/lib/python3.13/dist-packages (from unstructured[pdf]) (0.7.0)
# Requirement already satisfied: langdetect<2.0.0,>=1.0.9 in /usr/local/lib/python3.13/dist-packages (from unstructured[pdf]) (1.0.9)
# Requirement already satisfied: lxml<7.0.0,>=5.0.0 in /usr/local/lib/python3.13/dist-packages (from unstructured[pdf]) (6.1.2)
# Requirement already satisfied: nh3<1.0.0,>=0.3.0 in /usr/local/lib/python3.13/dist-packages (from unstructured[pdf]) (0.3.7)
# Requirement already satisfied: numba<1.0.0,>=0.60.0 in /usr/local/lib/python3.13/dist-packages (from unstructured[pdf]) (0.61.2)
# Requirement already satisfied: numpy<3.0.0,>=1.26.0 in /usr/local/lib/python3.13/dist-packages (from unstructured[pdf]) (2.1.3)
# Requirement already satisfied: psutil<8.0.0,>=7.2.2 in /usr/local/lib/python3.13/dist-packages (from unstructured[pdf]) (7.2.2)
# Requirement already satisfied: python-iso639<2027.0.0,>=2026.1.31 in /usr/local/lib/python3.13/dist-packages (from unstructured[pdf]) (2026.7.23)
# Requirement already satisfied: python-magic<1.0.0,>=0.4.27 in /usr/local/lib/python3.13/dist-packages (from unstructured[pdf]) (0.4.27)
# Requirement already satisfied: python-oxmsg<1.0.0,>=0.0.2 in /usr/local/lib/python3.13/dist-packages (from unstructured[pdf]) (0.0.2)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.14.3 in /usr/local/lib/python3.13/dist-packages (from unstructured[pdf]) (3.14.6)
# Requirement already satisfied: regex<2027.0.0,>=2024.0.0 in /usr/local/lib/python3.13/dist-packages (from unstructured[pdf]) (2025.11.3)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in /usr/local/lib/python3.13/dist-packages (from unstructured[pdf]) (2.34.2)
# Requirement already satisfied: spacy<4.0.0,>=3.7.0 in /usr/local/lib/python3.13/dist-packages (from unstructured[pdf]) (3.8.16)
# Requirement already satisfied: tqdm<5.0.0,>=4.67.3 in /usr/local/lib/python3.13/dist-packages (from unstructured[pdf]) (4.67.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.15.0 in /usr/local/lib/python3.13/dist-packages (from unstructured[pdf]) (4.16.0)
# Requirement already satisfied: unstructured-client<1.0.0,>=0.25.9 in /usr/local/lib/python3.13/dist-packages (from unstructured[pdf]) (0.46.2)
# Requirement already satisfied: wrapt<3.0.0,>=2.1.1 in /usr/local/lib/python3.13/dist-packages (from unstructured[pdf]) (2.4.0)
# Requirement already satisfied: google-cloud-vision<4.0.0,>=3.12.1 in /usr/local/lib/python3.13/dist-packages (from unstructured[pdf]) (3.15.0)
# Requirement already satisfied: pdf2image<2.0.0,>=1.17.0 in /usr/local/lib/python3.13/dist-packages (from unstructured[pdf]) (1.17.0)
# Requirement already satisfied: pdfminer-six<20270000,>=20251230 in /usr/local/lib/python3.13/dist-packages (from unstructured[pdf]) (20260107)
# Requirement already satisfied: pi-heif<2.0.0,>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from unstructured[pdf]) (1.4.0)
# Requirement already satisfied: pikepdf<11.0.0,>=10.3.0 in /usr/local/lib/python3.13/dist-packages (from unstructured[pdf]) (10.13.0.post1)
# Requirement already satisfied: pypdf<7.0.0,>=6.9.1 in /usr/local/lib/python3.13/dist-packages (from unstructured[pdf]) (6.19.0)
# Requirement already satisfied: unstructured-inference<2.0.0,>=1.6.12 in /usr/local/lib/python3.13/dist-packages (from unstructured[pdf]) (1.6.13)
# Requirement already satisfied: unstructured-pytesseract<1.0.0,>=0.3.15 in /usr/local/lib/python3.13/dist-packages (from unstructured[pdf]) (0.3.15)
# Requirement already satisfied: soupsieve>=1.6.1 in /usr/local/lib/python3.13/dist-packages (from beautifulsoup4<5.0.0,>=4.14.3->unstructured[pdf]) (2.9.2)
# Requirement already satisfied: google-api-core<3.0.0,>=2.17.1 in /usr/local/lib/python3.13/dist-packages (from google-api-core[grpc]<3.0.0,>=2.17.1->google-cloud-vision<4.0.0,>=3.12.1->unstructured[pdf]) (2.30.3)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in /usr/local/lib/python3.13/dist-packages (from google-cloud-vision<4.0.0,>=3.12.1->unstructured[pdf]) (2.49.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.59.0 in /usr/local/lib/python3.13/dist-packages (from google-cloud-vision<4.0.0,>=3.12.1->unstructured[pdf]) (1.83.1)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.13/dist-packages (from google-cloud-vision<4.0.0,>=3.12.1->unstructured[pdf]) (1.28.2)
# Requirement already satisfied: protobuf<8.0.0,>=4.25.8 in /usr/local/lib/python3.13/dist-packages (from google-cloud-vision<4.0.0,>=3.12.1->unstructured[pdf]) (5.29.6)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.13/dist-packages (from html5lib<2.0.0,>=1.1->unstructured[pdf]) (1.17.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.13/dist-packages (from html5lib<2.0.0,>=1.1->unstructured[pdf]) (0.6.1)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /usr/local/lib/python3.13/dist-packages (from numba<1.0.0,>=0.60.0->unstructured[pdf]) (0.44.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.13/dist-packages (from pdf2image<2.0.0,>=1.17.0->unstructured[pdf]) (11.3.0)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.13/dist-packages (from pdfminer-six<20270000,>=20251230->unstructured[pdf]) (50.0.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.13/dist-packages (from pikepdf<11.0.0,>=10.3.0->unstructured[pdf]) (26.3)
# Requirement already satisfied: click in /usr/local/lib/python3.13/dist-packages (from python-oxmsg<1.0.0,>=0.0.2->unstructured[pdf]) (8.5.0)
# Requirement already satisfied: olefile in /usr/local/lib/python3.13/dist-packages (from python-oxmsg<1.0.0,>=0.0.2->unstructured[pdf]) (0.47)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.32.5->unstructured[pdf]) (3.19)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.32.5->unstructured[pdf]) (2.5.0)
# Requirement already satisfied: certifi>=2023.5.7 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.32.5->unstructured[pdf]) (2026.7.22)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured[pdf]) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured[pdf]) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured[pdf]) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured[pdf]) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured[pdf]) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured[pdf]) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured[pdf]) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured[pdf]) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured[pdf]) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured[pdf]) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured[pdf]) (1.3.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured[pdf]) (0.27.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured[pdf]) (2.13.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured[pdf]) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.13/dist-packages (from spacy<4.0.0,>=3.7.0->unstructured[pdf]) (80.10.2)
# Requirement already satisfied: aiofiles>=25.1.0 in /usr/local/lib/python3.13/dist-packages (from unstructured-client<1.0.0,>=0.25.9->unstructured[pdf]) (25.1.0)
# Requirement already satisfied: httpcore>=1.0.9 in /usr/local/lib/python3.13/dist-packages (from unstructured-client<1.0.0,>=0.25.9->unstructured[pdf]) (1.0.9)
# Requirement already satisfied: httpx>=0.28.1 in /usr/local/lib/python3.13/dist-packages (from unstructured-client<1.0.0,>=0.25.9->unstructured[pdf]) (0.28.1)
# Requirement already satisfied: pypdfium2>=5.6.0 in /usr/local/lib/python3.13/dist-packages (from unstructured-client<1.0.0,>=0.25.9->unstructured[pdf]) (5.13.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from unstructured-client<1.0.0,>=0.25.9->unstructured[pdf]) (1.0.0)
# Requirement already satisfied: accelerate>=1.12.0 in /usr/local/lib/python3.13/dist-packages (from unstructured-inference<2.0.0,>=1.6.12->unstructured[pdf]) (1.14.0)
# Requirement already satisfied: huggingface-hub>=0.22.0 in /usr/local/lib/python3.13/dist-packages (from unstructured-inference<2.0.0,>=1.6.12->unstructured[pdf]) (1.29.0)
# Requirement already satisfied: matplotlib>=3.10.8 in /usr/local/lib/python3.13/dist-packages (from unstructured-inference<2.0.0,>=1.6.12->unstructured[pdf]) (3.11.2)
# Requirement already satisfied: onnx>=1.20.1 in /usr/local/lib/python3.13/dist-packages (from unstructured-inference<2.0.0,>=1.6.12->unstructured[pdf]) (1.22.0)
# Requirement already satisfied: onnxruntime>=1.25.0 in /usr/local/lib/python3.13/dist-packages (from unstructured-inference<2.0.0,>=1.6.12->unstructured[pdf]) (1.30.0)
# Requirement already satisfied: opencv-python>=4.13.0.90 in /usr/local/lib/python3.13/dist-packages (from unstructured-inference<2.0.0,>=1.6.12->unstructured[pdf]) (5.0.0.93)
# Requirement already satisfied: pandas>=1.5.0 in /usr/local/lib/python3.13/dist-packages (from unstructured-inference<2.0.0,>=1.6.12->unstructured[pdf]) (2.2.3)
# Requirement already satisfied: scipy>=1.17.0 in /usr/local/lib/python3.13/dist-packages (from unstructured-inference<2.0.0,>=1.6.12->unstructured[pdf]) (1.18.1)
# Requirement already satisfied: timm>=1.0.24 in /usr/local/lib/python3.13/dist-packages (from unstructured-inference<2.0.0,>=1.6.12->unstructured[pdf]) (1.0.29)
# Requirement already satisfied: torch>=2.10.0 in /usr/local/lib/python3.13/dist-packages (from unstructured-inference<2.0.0,>=1.6.12->unstructured[pdf]) (2.11.0+cu128)
# Requirement already satisfied: transformers>=4.25.1 in /usr/local/lib/python3.13/dist-packages (from unstructured-inference<2.0.0,>=1.6.12->unstructured[pdf]) (5.16.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.13/dist-packages (from accelerate>=1.12.0->unstructured-inference<2.0.0,>=1.6.12->unstructured[pdf]) (6.0.3)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.13/dist-packages (from accelerate>=1.12.0->unstructured-inference<2.0.0,>=1.6.12->unstructured[pdf]) (0.8.0)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from cryptography>=36.0.0->pdfminer-six<20270000,>=20251230->unstructured[pdf]) (2.1.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.63.2 in /usr/local/lib/python3.13/dist-packages (from google-api-core<3.0.0,>=2.17.1->google-api-core[grpc]<3.0.0,>=2.17.1->google-cloud-vision<4.0.0,>=3.12.1->unstructured[pdf]) (1.75.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.13/dist-packages (from google-api-core[grpc]<3.0.0,>=2.17.1->google-cloud-vision<4.0.0,>=3.12.1->unstructured[pdf]) (1.71.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.13/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-vision<4.0.0,>=3.12.1->unstructured[pdf]) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.13/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-vision<4.0.0,>=3.12.1->unstructured[pdf]) (4.9.1)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore>=1.0.9->unstructured-client<1.0.0,>=0.25.9->unstructured[pdf]) (0.16.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.13/dist-packages (from httpx>=0.28.1->unstructured-client<1.0.0,>=0.25.9->unstructured[pdf]) (4.14.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub>=0.22.0->unstructured-inference<2.0.0,>=1.6.12->unstructured[pdf]) (2025.12.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.2 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub>=0.22.0->unstructured-inference<2.0.0,>=1.6.12->unstructured[pdf]) (1.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.10.8->unstructured-inference<2.0.0,>=1.6.12->unstructured[pdf]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.10.8->unstructured-inference<2.0.0,>=1.6.12->unstructured[pdf]) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.10.8->unstructured-inference<2.0.0,>=1.6.12->unstructured[pdf]) (4.64.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.10.8->unstructured-inference<2.0.0,>=1.6.12->unstructured[pdf]) (1.5.1)
# Requirement already satisfied: pyparsing>=3 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.10.8->unstructured-inference<2.0.0,>=1.6.12->unstructured[pdf]) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.10.8->unstructured-inference<2.0.0,>=1.6.12->unstructured[pdf]) (2.9.0.post0)
# Requirement already satisfied: ml_dtypes>=0.5.4 in /usr/local/lib/python3.13/dist-packages (from onnx>=1.20.1->unstructured-inference<2.0.0,>=1.6.12->unstructured[pdf]) (0.6.0)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.13/dist-packages (from onnxruntime>=1.25.0->unstructured-inference<2.0.0,>=1.6.12->unstructured[pdf]) (25.12.19)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas>=1.5.0->unstructured-inference<2.0.0,>=1.6.12->unstructured[pdf]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas>=1.5.0->unstructured-inference<2.0.0,>=1.6.12->unstructured[pdf]) (2026.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.0.0->spacy<4.0.0,>=3.7.0->unstructured[pdf]) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.0.0->spacy<4.0.0,>=3.7.0->unstructured[pdf]) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.0.0->spacy<4.0.0,>=3.7.0->unstructured[pdf]) (0.4.4)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.13/dist-packages (from thinc<8.4.0,>=8.3.12->spacy<4.0.0,>=3.7.0->unstructured[pdf]) (1.3.3)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.13/dist-packages (from timm>=1.0.24->unstructured-inference<2.0.0,>=1.6.12->unstructured[pdf]) (0.26.0+cu128)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.13/dist-packages (from torch>=2.10.0->unstructured-inference<2.0.0,>=1.6.12->unstructured[pdf]) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.13/dist-packages (from torch>=2.10.0->unstructured-inference<2.0.0,>=1.6.12->unstructured[pdf]) (3.6.1)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.10.0->unstructured-inference<2.0.0,>=1.6.12->unstructured[pdf]) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.13/dist-packages (from torch>=2.10.0->unstructured-inference<2.0.0,>=1.6.12->unstructured[pdf]) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.13/dist-packages (from torch>=2.10.0->unstructured-inference<2.0.0,>=1.6.12->unstructured[pdf]) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.13/dist-packages (from torch>=2.10.0->unstructured-inference<2.0.0,>=1.6.12->unstructured[pdf]) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.13/dist-packages (from torch>=2.10.0->unstructured-inference<2.0.0,>=1.6.12->unstructured[pdf]) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.13/dist-packages (from torch>=2.10.0->unstructured-inference<2.0.0,>=1.6.12->unstructured[pdf]) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.13/dist-packages (from torch>=2.10.0->unstructured-inference<2.0.0,>=1.6.12->unstructured[pdf]) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.10.0->unstructured-inference<2.0.0,>=1.6.12->unstructured[pdf]) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.10.0->unstructured-inference<2.0.0,>=1.6.12->unstructured[pdf]) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.10.0->unstructured-inference<2.0.0,>=1.6.12->unstructured[pdf]) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.10.0->unstructured-inference<2.0.0,>=1.6.12->unstructured[pdf]) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.10.0->unstructured-inference<2.0.0,>=1.6.12->unstructured[pdf]) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.10.0->unstructured-inference<2.0.0,>=1.6.12->unstructured[pdf]) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.10.0->unstructured-inference<2.0.0,>=1.6.12->unstructured[pdf]) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.10.0->unstructured-inference<2.0.0,>=1.6.12->unstructured[pdf]) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.10.0->unstructured-inference<2.0.0,>=1.6.12->unstructured[pdf]) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.10.0->unstructured-inference<2.0.0,>=1.6.12->unstructured[pdf]) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.10.0->unstructured-inference<2.0.0,>=1.6.12->unstructured[pdf]) (12.8.90)
# Requirement already satisfied: tokenizers<0.24.0,>=0.23.1 in /usr/local/lib/python3.13/dist-packages (from transformers>=4.25.1->unstructured-inference<2.0.0,>=1.6.12->unstructured[pdf]) (0.23.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.13/dist-packages (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured[pdf]) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.13/dist-packages (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured[pdf]) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.13/dist-packages (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured[pdf]) (0.0.5)
# Requirement already satisfied: cloudpathlib>=0.7.0 in /usr/local/lib/python3.13/dist-packages (from weasel<2.0.0,>=1.0.0->spacy<4.0.0,>=3.7.0->unstructured[pdf]) (0.25.0)
# Requirement already satisfied: smart-open>=5.2.1 in /usr/local/lib/python3.13/dist-packages (from weasel<2.0.0,>=1.0.0->spacy<4.0.0,>=3.7.0->unstructured[pdf]) (8.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->spacy<4.0.0,>=3.7.0->unstructured[pdf]) (3.0.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.13/dist-packages (from cffi>=2.0.0->cryptography>=36.0.0->pdfminer-six<20270000,>=20251230->unstructured[pdf]) (3.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.13/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=2.10.0->unstructured-inference<2.0.0,>=1.6.12->unstructured[pdf]) (1.8.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.13/dist-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-vision<4.0.0,>=3.12.1->unstructured[pdf]) (0.6.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.13/dist-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured[pdf]) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.13/dist-packages (from rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured[pdf]) (2.21.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sympy>=1.13.3->torch>=2.10.0->unstructured-inference<2.0.0,>=1.6.12->unstructured[pdf]) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.13/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.7.0->unstructured[pdf]) (0.1.2)

# %%
documents = loader.load()
documents
# Out:
# WARNING:unstructured:No languages specified, defaulting to English.
# [Document(metadata={'source': 'python_built_in_functions.pdf'}, page_content='Python Built-In Functions\n\nGaurav Kr. suman\n\nMIT5\n\n1. abs()\n\nThe abs() is one of the most popular Python built-in functions, which returns the absolute value of a number. A negative value’s absolute is that value is positive.\n\n>>> abs(-7)\n\n7\n\n>>> abs(7)\n\n7\n\n>>> abs(0)\n\n2. all()\n\nThe all() function takes a container as an argument. This Built in Functions returns True if all values in a python iterable have a Boolean value of True. An empty value has a Boolean value of False.\n\n>>> all({\'*\',\'\',\'\'})\n\nFalse\n\n>>> all([\' \',\' \',\' \'])\n\nTrue\n\n3. any()\n\nLike all(), it takes one argument and returns True if, even one value in the iterable has a Boolean value of True.\n\n>>> any((1,0,0))\n\nTrue\n\n>>> any((0,0,0))\n\nFalse\n\n4. ascii()\n\nIt is important Python built-in functions, returns a printable representation of a python object (like a string or a Python list). Let’s take a Romanian character.\n\n1 | P a g e\n\n>>> ascii(\'ș\')\n\n“‘\\\\u0219′”\n\nSince this was a non-ASCII character in python, the interpreter added a backslash (\\) and escaped it using another backslash.\n\n>>> ascii(\'ușor\')\n\n“‘u\\\\u0219or\'”\n\nLet’s apply it to a list.\n\n>>> ascii([\'s\',\'ș\'])\n\n“[‘s’, ‘\\\\u0219’]”\n\n5. bin()\n\nbin() converts an integer to a binary string. We have seen this and other functions in our article on Python Numbers.\n\n>>> bin(7)\n\n‘0b111’\n\nWe can’t apply it on floats, though.\n\n>>> bin(7.0)\n\nTraceback (most recent call last):\n\nFile “<pyshell#20>”, line 1, in <module>\n\nbin(7.0)\n\nTypeError: ‘float’ object cannot be interpreted as an integer\n\n6. bool()\n\nbool() converts a value to Boolean.\n\n>>> bool(0.5)\n\nTrue\n\n>>> bool(\'\')\n\nFalse\n\n>>> bool(True)\n\nTrue\n\n7. bytearray()\n\n2 | P a g e\n\nbytearray() returns a python array of a given byte size.\n\n>>> a=bytearray(4)\n\n>>> a\n\nbytearray(b’\\x00\\x00\\x00\\x00′)\n\n>>> a.append(1)\n\n>>> a\n\nbytearray(b’\\x00\\x00\\x00\\x00\\x01′)\n\n>>> a[0]=1\n\n>>> a\n\nbytearray(b’\\x01\\x00\\x00\\x00\\x01′)\n\n>>> a[0]\n\n1\n\nLet’s do this on a list.\n\n>>> bytearray([1,2,3,4])\n\nbytearray(b’\\x01\\x02\\x03\\x04′)\n\n8. bytes()\n\nbytes() returns an immutable bytes object.\n\n>>> bytes(5)\n\nb’\\x00\\x00\\x00\\x00\\x00′\n\n>>> bytes([1,2,3,4,5])\n\nb’\\x01\\x02\\x03\\x04\\x05′\n\n>>> bytes(\'hello\',\'utf-8\')\n\nb’hello’\n\nHere, utf-8 is the encoding.\n\nBoth bytes() and bytearray() deal with raw data, but bytearray() is mutable, while bytes() is immutable.\n\n>>> a=bytes([1,2,3,4,5])\n\n>>> a\n\nb’\\x01\\x02\\x03\\x04\\x05′\n\n>>> a[4]=\n\n3 | P a g e\n\n3\n\nTraceback (most recent call last):\n\nFile “<pyshell#46>”, line 1, in <module>\n\na[4]=3\n\nTypeError: ‘bytes’ object does not support item assignment\n\nLet’s try this on bytearray().\n\n>>> a=bytearray([1,2,3,4,5])\n\n>>> a\n\nbytearray(b’\\x01\\x02\\x03\\x04\\x05′)\n\n>>> a[4]=3\n\n>>> a\n\nbytearray(b’\\x01\\x02\\x03\\x04\\x03′)\n\n9. callable()\n\ncallable() tells us if an object can be called.\n\n>>> callable([1,2,3])\n\nFalse\n\n>>> callable(callable)\n\nTrue\n\n>>> callable(False)\n\nFalse\n\n>>> callable(list)\n\nTrue\n\nA function is callable, a list is not. Even the callable() python Built In function is callable.\n\n10. chr()\n\nchr() Built In function returns the character in python for an ASCII value.\n\n>>> chr(65)\n\n‘A’\n\n>>> chr(97)\n\n4 | P a g e\n\n‘a’\n\n>>> chr(9)\n\n‘\\t’\n\n>>> chr(48)\n\n‘0’\n\n11. classmethod()\n\nclassmethod() returns a class method for a given method.\n\n>>> class fruit:\n\ndef sayhi(self):\n\nprint("Hi, I\'m a fruit")\n\n>>> fruit.sayhi=classmethod(fruit.sayhi)\n\n>>> fruit.sayhi()\n\nHi, I’m a fruit\n\nWhen we pass the method sayhi() as an argument to classmethod(), it converts it into a python class method one that belongs to the class. Then, we call it like we would call any static method in python without an object.\n\n12. co ...

# %%
text_splitter = CharacterTextSplitter(chunk_size=2000, chunk_overlap=400)

# %%
texts = text_splitter.split_documents(documents)

# %%
type(texts)
# Out:
# list

# %%
len(texts)
# Out:
# 7

# %%
texts[1]
# Out:
# Document(metadata={'source': 'python_built_in_functions.pdf'}, page_content='False\n\n>>> bool(True)\n\nTrue\n\n7. bytearray()\n\n2 | P a g e\n\nbytearray() returns a python array of a given byte size.\n\n>>> a=bytearray(4)\n\n>>> a\n\nbytearray(b’\\x00\\x00\\x00\\x00′)\n\n>>> a.append(1)\n\n>>> a\n\nbytearray(b’\\x00\\x00\\x00\\x00\\x01′)\n\n>>> a[0]=1\n\n>>> a\n\nbytearray(b’\\x01\\x00\\x00\\x00\\x01′)\n\n>>> a[0]\n\n1\n\nLet’s do this on a list.\n\n>>> bytearray([1,2,3,4])\n\nbytearray(b’\\x01\\x02\\x03\\x04′)\n\n8. bytes()\n\nbytes() returns an immutable bytes object.\n\n>>> bytes(5)\n\nb’\\x00\\x00\\x00\\x00\\x00′\n\n>>> bytes([1,2,3,4,5])\n\nb’\\x01\\x02\\x03\\x04\\x05′\n\n>>> bytes(\'hello\',\'utf-8\')\n\nb’hello’\n\nHere, utf-8 is the encoding.\n\nBoth bytes() and bytearray() deal with raw data, but bytearray() is mutable, while bytes() is immutable.\n\n>>> a=bytes([1,2,3,4,5])\n\n>>> a\n\nb’\\x01\\x02\\x03\\x04\\x05′\n\n>>> a[4]=\n\n3 | P a g e\n\n3\n\nTraceback (most recent call last):\n\nFile “<pyshell#46>”, line 1, in <module>\n\na[4]=3\n\nTypeError: ‘bytes’ object does not support item assignment\n\nLet’s try this on bytearray().\n\n>>> a=bytearray([1,2,3,4,5])\n\n>>> a\n\nbytearray(b’\\x01\\x02\\x03\\x04\\x05′)\n\n>>> a[4]=3\n\n>>> a\n\nbytearray(b’\\x01\\x02\\x03\\x04\\x03′)\n\n9. callable()\n\ncallable() tells us if an object can be called.\n\n>>> callable([1,2,3])\n\nFalse\n\n>>> callable(callable)\n\nTrue\n\n>>> callable(False)\n\nFalse\n\n>>> callable(list)\n\nTrue\n\nA function is callable, a list is not. Even the callable() python Built In function is callable.\n\n10. chr()\n\nchr() Built In function returns the character in python for an ASCII value.\n\n>>> chr(65)\n\n‘A’\n\n>>> chr(97)\n\n4 | P a g e\n\n‘a’\n\n>>> chr(9)\n\n‘\\t’\n\n>>> chr(48)\n\n‘0’\n\n11. classmethod()\n\nclassmethod() returns a class method for a given method.\n\n>>> class fruit:\n\ndef sayhi(self):\n\nprint("Hi, I\'m a fruit")\n\n>>> fruit.sayhi=classmethod(fruit.sayhi)\n\n>>> fruit.sayhi()\n\nHi, I’m a fruit\n\nWhen we pass the method sayhi() as an argument to classmethod(), it converts it into a python class method one that belongs to the class. Then, we call it like we would call any static method in python without an object.\n\n12. compile()')

# %%
embeddings = HuggingFaceEmbeddings()
# Out:
# /tmp/ipykernel_8673/3655315981.py:1: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings()
# /tmp/ipykernel_8673/3655315981.py:1: LangChainDeprecationWarning: Default values for HuggingFaceEmbeddings.model_name were deprecated in LangChain 0.2.16 and will be removed in 0.4.0. Explicitly pass a model_name to the HuggingFaceEmbeddings constructor instead.
#   embeddings = HuggingFaceEmbeddings()
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/11.6k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B /  438MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
persist_directory = "vector_db"

# %%
vector_db = Chroma.from_documents(
    documents=texts,
    embedding=embeddings,
    persist_directory=persist_directory
)

# %%
# retriever
retriever = vector_db.as_retriever()

# %%
# !pip install -U langchain-groq

from langchain_groq import ChatGroq
# Out:
# Requirement already satisfied: langchain-groq in /usr/local/lib/python3.13/dist-packages (1.1.3)
# Requirement already satisfied: groq<1.0.0,>=0.30.0 in /usr/local/lib/python3.13/dist-packages (from langchain-groq) (0.37.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from langchain-groq) (1.6.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.13/dist-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (4.14.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.13/dist-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.13/dist-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (2.13.5)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.13/dist-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.13/dist-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (4.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain-groq) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain-groq) (0.0.19)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain-groq) (0.12.1)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain-groq) (26.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain-groq) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain-groq) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.4.0->langchain-groq) (0.17.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.13/dist-packages (from anyio<5,>=3.5.0->groq<1.0.0,>=0.30.0->langchain-groq) (3.19)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.13/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain-groq) (3.1.1)
# Requirement already satisfied: httpx2<3,>=2 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (2.12.0)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (3.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (2.34.2)
# Requirement already satisfied: websockets>=15.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (4.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in /usr/local/lib/python3.13/dist-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.4.4)
# Requirement already satisfied: httpcore2==2.12.0 in /usr/local/lib/python3.13/dist-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (2.12.0)
# Requirement already satisfied: truststore>=0.10 in /usr/local/lib/python3.13/dist-packages (from httpx2<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (0.10.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.13/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (2.5.0)

# %%
# llm from groq
llm = ChatGroq(
    model="openai/gpt-oss-20b",
    temperature=0
)

# %%
qa_chain = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=retriever,
    return_source_documents=True
)

# %%
# invoke the qa chain and get a response for user query
query = "what are the function from this pdf "
response = qa_chain.invoke({"query": query})

# %%
print(response)
# Out:
# {'query': 'what are the function from this pdf ', 'result': '', 'source_documents': [Document(id='c13358dd-b40e-49e9-a3a8-1651fd3026cc', metadata={'source': 'python_built_in_functions.pdf'}, page_content='>>> divmod(3,7)\n\n6 | P a g e\n\n(0, 3)\n\n>>> divmod(7,3)\n\n(2, 1) If you encounter any doubt in Python Built-in Function, Please Comment.\n\n17. enumerate()\n\nThis Python Built In function returns an enumerate object. In other words, it adds a counter to the iterable.\n\n>>> for i in enumerate([\'a\',\'b\',\'c\']):\n\nprint(i)\n\n(0, ‘a’) (1, ‘b’) (2, ‘c’)\n\n18. eval()\n\nThis Function takes a string as an argument, which is parsed as an expression.\n\n>>> x=7\n\n>>> eval(\'x+7\')\n\n14\n\n>>> eval(\'x+(x%2)\')\n\n8\n\n19. exec()\n\nexec() runs Python code dynamically.\n\n>>> exec(\'a=2;b=3;print(a+b)\')\n\n5\n\n>>> exec(input("Enter your program"))\n\nEnter your programprint(2+3)\n\n5\n\n20. filter()\n\n7 | P a g e\n\nLike we’ve seen in python Lambda Expressios, filter() filters out the items for which the condition is True.\n\n>>> list(filter(lambda x:x%2==0,[1,2,0,False]))\n\n[2, 0, False]\n\n21. float()\n\nThis Python Built In function converts an int or a compatible value into a float.\n\n>>> float(2)\n\n2.0\n\n>>> float(\'3\')\n\n3.0\n\n>>> float(\'3s\')\n\nTraceback (most recent call last):\n\nFile “<pyshell#136>”, line 1, in <module>\n\nfloat(‘3s’)\n\nValueError: could not convert string to float: ‘3s’\n\n>>> float(False)\n\n0.0\n\n>>> float(4.7)\n\n4.7\n\n22. format()\n\nWe have seen this Python built-in function, one in our lesson on Python Strings.\n\n>>> a,b=2,3\n\n>>> print("a={0} and b={1}".format(a,b))\n\na=2 and b=3\n\n>>> print("a={a} and b={b}".format(a=3,b=4))\n\na=3 and b=4\n\n23. frozenset()\n\nfrozenset() returns an immutable frozenset object.\n\n8 | P a g e\n\n>>> frozenset((3,2,4))\n\nfrozenset({2, 3, 4})\n\nRead Python Sets and Booleans for more on frozenset.\n\n24. getattr()\n\ngetattr() returns the value of an object’s attribute.\n\n>>> getattr(orange,\'size\')\n\n7\n\n25. globals()\n\nThis Python built-in functions, returns a dictionary of the current global symbol table.\n\n>>> globals()'), Document(id='92910ab0-76fb-499b-ae87-6a0a1e403c8f', metadata={'source': 'python_built_in_functions.pdf'}, page_content='Input() Python built-in functions, reads and returns a line of string.\n\n>>> input("Enter a number")\n\nEnter a number7 ‘7’\n\n10 | P a g e\n\nNote that this returns the input as a string. If we want to take 7 as an integer, we need to apply the int() function to it.\n\n>>> int(input("Enter a number"))\n\nEnter a number7\n\n7\n\n31. int()\n\nint() converts a value to an integer.\n\n>>> int(\'7\')\n\n7\n\n32. isinstance()\n\nWe have seen this one in previous lessons. isinstance() takes a variable and a class as arguments. Then, it returns True if the variable belongs to the class. Otherwise, it returns False.\n\n>>> isinstance(0,str)\n\nFalse\n\n>>> isinstance(orange,fruit)\n\nTrue\n\n33. ord()\n\nThe function ord() returns an integer that represents the Unicode point for a given Unicode character.\n\n>>> ord(\'A\')\n\n65\n\n>>> ord(\'9\')\n\n57 This is complementary to chr().\n\n>>> chr(65)\n\n‘A’\n\n34. pow()\n\npow() takes two arguments- say, x and y. It then returns the value of x to the power of y.\n\n11 | P a g e\n\n>>> pow(3,4)\n\n81\n\n>>> pow(7,0)\n\n1\n\n>>> pow(7,-1)\n\n0.14285714285714285\n\n>>> pow(7,-2)\n\n0.02040816326530612\n\n35. print()\n\nWe don’t think we need to explain this anymore. We’ve been seeing this function since the beginning of this article.\n\n>>> print("Okay, next function, please!")\n\nOkay, next function, please!\n\n36. range()\n\nWe’ve taken a whole tutorial on this. Read up range() in Python.\n\n>>> for i in range(7,2,-2):\n\nprint(i)\n\n7 5 3\n\n37. repr()\n\nrepr() returns a representable string of an object.\n\n>>> repr("Hello")\n\n“‘Hello\'”\n\n>>> repr(7)\n\n‘7’\n\n>>> repr(False)\n\n‘False’\n\n38. reversed()\n\n12 | P a g e\n\nThis functions rev ...

# %%
print(response["result"])

# %%
print(response["source_documents"][0].metadata["source"])
# Out:
# python_built_in_functions.pdf

# %%
# invoke the qa chain and get a response for user query
query = "Give me summary of all function from this pdf?"
response = qa_chain.invoke({"query": query})
print(response["result"])
print("*"*30)
print("Source Document:", response["source_documents"][0].metadata["source"])
# Out:
# **Summary of Python Built‑In Functions (as presented in the PDF)**
#
# | # | Function | What it does | Typical usage / example |
# |---|----------|--------------|------------------------|
# | 1 | **`abs()`** | Returns the absolute value of a number. | `abs(-7)` → `7` |
# | 2 | **`all()`** | Returns `True` if *every* element in an iterable is truthy (or if the iterable is empty). | `all([True, 1, "x"])` → `True` |
# | 3 | **`any()`** | Returns `True` if *at least one* element in an iterable is truthy. | `any([0, False, "yes"])` → `True` |
# | 4 | **`ascii()`** | Returns a printable representation of an object, escaping non‑ASCII characters. | `ascii('ș')` → `'\\u0219'` |
# | 5 | **`bin()`** | Converts an integer to its binary string representation. | `bin(7)` → `'0b111'` |
# | 6 | **`bool()`** | Converts a value to a Boolean (`True`/`False`). | `bool('')` → `False` |
# | 7 | **`bytearray()`** | Creates a mutable array of bytes. | `bytearray([1,2,3])` → `bytearray(b'\x01\x02\x03')` |
# | 8 | **`bytes()`** | Creates an immutable bytes object. | `bytes([65, 66])` → `b'AB'` |
# | 9 | **`chr()`** | (Mentioned in the `ord()` section) Returns the character for a given Unicode code point. | `chr(65)` → `'A'` |
# |10 | **`divmod()`** | Returns a tuple `(quotient, remainder)` for two numbers. | `divmod(7,3)` → `(2,1)` |
# |11 | **`enumerate()`** | Adds a counter to an iterable, yielding `(index, value)` tuples. | `list(enumerate(['a','b']))` → `[(0,'a'),(1,'b')]` |
# |12 | **`eval()`** | Evaluates a string as a Python expression and returns the result. | `eval('x+7')` (with `x=7`) → `14` |
# |13 | **`exec()`** | Executes Python code contained in a string (or file). | `exec('a=2;print(a)')` → prints `2` |
# |14 | **`filter()`** | Filters an iterable, keeping only elements that satisfy a predicate. | `list(filter(lambda x: x%2==0, [1,2,3]))` → `[2]` |
# |15 | **`float()`** | Converts a number or string to a floating‑point number. | `float('3')` → `3.0` |
# |16 | **`format()`** | Formats a string using placeholders. | `"a={0}".format(3)` → `'a=3'` |
# |17 | **`frozenset()`** | Creates an immutable set. | `frozenset((3,2,4))` → `frozenset({2,3,4})` |
# |18 | **`getattr()`** | Retrieves the value of an attribute from an object. | `getattr(obj, 'size')` |
# |19 | **`globals()`** | Returns a dictionary representing the current global symbol table. | `globals()` → `{...}` |
# |20 | **`input()`** | Reads a line from standard input and returns it as a string. | `int(input('Enter a number: '))` |
# |21 | **`int()`** | Converts a value to an integer. | `int('7')` → `7` |
# |22 | **`isinstance()`** | Checks if an object is an instance of a given class/type. | `isinstance(5, int)` → `True` |
# |23 | **`ord()`** | Returns the Unicode code point of a single character. | `ord('A')` → `65` |
# |24 | **`pow()`** | Raises a number to a power (supports negative exponents). | `pow(3,4)` → `81` |
# |25 | **`print()`** | Outputs objects to the console (or another stream). | `print('Hello')` |
# |26 | **`range()`** | Generates a sequence of integers (used in loops). | `list(range(5))` → `[0,1,2,3,4]` |
# |27 | **`repr()`** | Returns a string that would recreate the object if `eval()`ed. | `repr('Hello')` → `"'Hello'"` |
# |28 | **`reversed()`** | Returns an iterator that yields elements of an iterable in reverse order. | `list(reversed([1,2,3]))` → `[3,2,1]` |
# |29 | **`round()`** | Rounds a float to a specified number of decimal places (or to a power of ten). | `round(3.777,2)` → `3.78` |
# |30 | **`set()`** | Creates a set (unordered collection of unique items). | `set([1,2,2,3])` → `{1,2,3}` |
# |31 | **`setattr()`** | Sets the value of an attribute on an object. | `setattr(obj, 'size', 8)` |
#
# **Notes & Highlights**
#
# - **`eval()`** and **`exec()`** should be used with caution, especially on untrusted input, because they execute arbitrary code.
# - **`globals()`** and **`locals()`** give access to the current symbol tables; useful for introspection or dynamic code.
# - **`round()`** accepts a negative second argument to round to tens, hundreds, etc. (`round(377.77, -1)` → `380.0`).
# - **`frozenset()`** is the immutable counterpart to `set()`, useful as dictionary keys or set elements.
# - **`bytearray()`** is mutable; you can append or modify individual bytes. **`bytes()`** is immutable.
# - **`enumerate()`** is often used in `for` loops when you need both the index and the value.
#
# This table captures all the built‑in functions that were explicitly described in the PDF excerpt you provided.
# ******************************
# Source Document: python_built_in_functions.pdf
