# %%
import os
os.environ["OPENROUTER_API_KEY"] = ''

# %% [markdown]
# # **DEEPSEEK MODEL**

# %%
# !pip install openai
# !pip install openrouter
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.13/dist-packages (2.54.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.13/dist-packages (from openai) (4.14.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.13/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.13/dist-packages (from openai) (0.16.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.13/dist-packages (from openai) (2.12.5)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.13/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.13/dist-packages (from openai) (4.67.3)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /usr/local/lib/python3.13/dist-packages (from openai) (4.16.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.13/dist-packages (from anyio<5,>=3.5.0->openai) (3.19)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->openai) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic<3,>=1.9.0->openai) (0.8.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /usr/local/lib/python3.13/dist-packages (from pydantic<3,>=1.9.0->openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic<3,>=1.9.0->openai) (0.4.4)
# Requirement already satisfied: openrouter in /usr/local/lib/python3.13/dist-packages (1.2.19)
# Requirement already satisfied: httpcore>=1.0.9 in /usr/local/lib/python3.13/dist-packages (from openrouter) (1.0.9)
# Requirement already satisfied: httpx>=0.28.1 in /usr/local/lib/python3.13/dist-packages (from openrouter) (0.28.1)
# Requirement already satisfied: jsonpath-python>=1.0.6 in /usr/local/lib/python3.13/dist-packages (from openrouter) (1.1.6)
# Requirement already satisfied: pydantic<2.13,>=2.11.2 in /usr/local/lib/python3.13/dist-packages (from openrouter) (2.12.5)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpcore>=1.0.9->openrouter) (2026.7.22)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore>=1.0.9->openrouter) (0.16.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.13/dist-packages (from httpx>=0.28.1->openrouter) (4.14.2)
# Requirement already satisfied: idna in /usr/local/lib/python3.13/dist-packages (from httpx>=0.28.1->openrouter) (3.19)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic<2.13,>=2.11.2->openrouter) (0.8.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /usr/local/lib/python3.13/dist-packages (from pydantic<2.13,>=2.11.2->openrouter) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.13/dist-packages (from pydantic<2.13,>=2.11.2->openrouter) (4.16.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic<2.13,>=2.11.2->openrouter) (0.4.4)

# %%
import requests
import json

api_key = ""

response = requests.post(
    "https://openrouter.ai/api/v1/chat/completions",
    headers={
        "Authorization": f"Bearer {api_key}",
        "Content-Type": "application/json",
    },
    json={
        "model": "deepseek/deepseek-r1:free",
        "messages": [
            {
                "role": "user",
                "content": "How many r's are in the word 'strawberry'?"
            }
        ]
    }
)

result = response.json()

if response.ok:
    answer = result["choices"][0]["message"]["content"]
    print(answer)
else:
    print("Error:", result)
# Out:
# Error: {'error': {'message': 'This model is unavailable for free. The paid version is available now - use this slug instead: deepseek/deepseek-r1', 'code': 404}, 'user_id': 'user_3JiJ4dJGAEAxLAl90kH52znLbcp'}

# %% [markdown]
# # **KIMI MODEL**

# %%
from openai import OpenAI

client = OpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key="")

response = client.chat.completions.create(
    model="moonshotai/kimi-k2.5",
    messages=[
        {
            "role": "user",
            "content": "How many r's are in the word 'strawberry'?"
        }
    ],
    max_tokens=1000,
    extra_body={
        "reasoning": {
            "enabled": True
        }
    }
)

assistant_message = response.choices[0].message


messages = [
    {
        "role": "user",
        "content": "How many r's are in the word 'strawberry'?"
    },
    {
        "role": "assistant",
        "content": assistant_message.content,
        "reasoning_details": assistant_message.reasoning_details
    },
    {
        "role": "user",
        "content": "Are you sure? Think carefully."
    }
]

response2 = client.chat.completions.create(
    model="moonshotai/kimi-k2.5",
    messages=messages,
    max_tokens=1000,
    extra_body={
        "reasoning": {
            "enabled": True
        }
    }
)

print(response2.choices[0].message.content)
# Out:
# Yes, I've double-checked carefully.
#
# The word is spelled: **S-T-R-A-W-B-E-R-R-Y**
#
# There are exactly **3** r's:
# 1. St**r**awberry
# 2. Strawbe**r**ry
# 3. Strawber**r**y

# %% [markdown]
# # **GEMMA MODEL**

# %%
import requests
import json

response = requests.post(
  url="https://openrouter.ai/api/v1/chat/completions",
  headers={
    "Authorization": "Bearer ",
    "Content-Type": "application/json",
      },
  data=json.dumps({
    "model": "google/gemma-4-31b-it:free",
    "messages": [
      {
        "role": "user",
        "content": "How many r's are in the word 'strawberry'?"
      }
    ]
  })
)

response = response.json()
#response = response['choices'][0]['message']['content']
print(response)
# Out:
# {'id': 'gen-1790168789-mPfeaFT7VfBxPppVX7pP', 'object': 'chat.completion', 'created': 1790168789, 'model': 'google/gemma-4-31b-it:free', 'provider': 'Google AI Studio', 'system_fingerprint': None, 'service_tier': 'default', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'native_finish_reason': 'STOP', 'message': {'role': 'assistant', 'content': "There are 3 r's in strawberry.", 'refusal': None, 'reasoning': None}}], 'usage': {'prompt_tokens': 13, 'completion_tokens': 10, 'total_tokens': 23, 'cost': 0, 'is_byok': False, 'prompt_tokens_details': {'cached_tokens': 0, 'cache_write_tokens': 0, 'audio_tokens': 0, 'video_tokens': 0}, 'cost_details': {'upstream_inference_cost': 0, 'upstream_inference_prompt_cost': 0, 'upstream_inference_completions_cost': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'image_tokens': 0, 'audio_tokens': 0}}}

# %% [markdown]
# # **NEMOTRON**

# %%
import requests
import os

api_key = os.getenv("OPENROUTER_API_KEY")

response = requests.post(
    url="https://openrouter.ai/api/v1/chat/completions",
    headers={
        "Authorization": f"Bearer ",
        "Content-Type": "application/json",
    },
    json={
        "model": "nvidia/nemotron-3-ultra-550b-a55b:free",
        "messages": [
            {
                "role": "user",
                "content": "How many r's are in the word 'strawberry'?"
            }
        ]
    }
)

result = response.json()
print(result["choices"][0]["message"]["content"])
# Out:
# There are **3** r's in "strawberry".
#
# Here is the breakdown: st**r**awbe**rr**y.

# %% [markdown]
# # **llAMA**

# %%
import requests
import os

api_key = os.getenv("OPENROUTER_API_KEY")

response = requests.post(
    url="https://openrouter.ai/api/v1/chat/completions",
    headers={
        "Authorization": f"Bearer ",
        "Content-Type": "application/json",
    },
    json={
        "model": "meta-llama/llama-3.3-70b-instruct:free",
        "messages": [
            {
                "role": "user",
                "content": "How many r's are in the word 'strawberry'?"
            }
        ]
    }
)

result = response.json()
print(result)
# Out:
# {'error': {'message': 'This model is unavailable for free. The paid version is available now - use this slug instead: meta-llama/llama-3.3-70b-instruct', 'code': 404}, 'user_id': 'user_3JiJ4dJGAEAxLAl90kH52znLbcp'}

# %% [markdown]
# # **QWEN**

# %%
import requests
import os

api_key = os.getenv("OPENROUTER_API_KEY")

response = requests.post(
    url="https://openrouter.ai/api/v1/chat/completions",
    headers={
        "Authorization": f"Bearer ",
        "Content-Type": "application/json",
    },
    json={
        "model": "qwen/qwen3-8b:free",
        "messages": [
            {
                "role": "user",
                "content": "How many r's are in the word 'strawberry'?"
            }
        ]
    }
)

result = response.json()
print(result)
# Out:
# {'error': {'message': 'This model is unavailable for free. The paid version is available now - use this slug instead: qwen/qwen3-8b', 'code': 404}, 'user_id': 'user_3JiJ4dJGAEAxLAl90kH52znLbcp'}

# %% [markdown]
# # **MISTRAL**

# %%
import requests
import os

api_key = os.getenv("OPENROUTER_API_KEY")

response = requests.post(
    url="https://openrouter.ai/api/v1/chat/completions",
    headers={
        "Authorization": f"Bearer",
        "Content-Type": "application/json",
    },
    json={
        "model": "mistralai/mistral-small-3.1-24b-instruct:free",
        "messages": [
            {
                "role": "user",
                "content": "How many r's are in the word 'strawberry'?"
            }
        ]
    }
)

result = response.json()
print(result)
# Out:
# {'error': {'message': 'This model is unavailable for free. The paid version is available now - use this slug instead: mistralai/mistral-small-3.1-24b-instruct', 'code': 404}, 'user_id': 'user_3JiJ4dJGAEAxLAl90kH52znLbcp'}

# %% [markdown]
# # **GEMMA**

# %%
import requests
import os

api_key = os.getenv("OPENROUTER_API_KEY")

response = requests.post(
    url="https://openrouter.ai/api/v1/chat/completions",
    headers={
        "Authorization": f"Bearer ",
        "Content-Type": "application/json",
    },
    json={
       "model": "google/gemma-4-26b-a4b-it:free",
        "messages": [
            {
                "role": "user",
                "content": "How many r's are in the word 'strawberry'?"
            }
        ]
    }
)

result = response.json()
#print(result["choices"][0]["message"]["content"])
print(result)
# Out:
# {'id': 'gen-1790169655-s69BCLleZWgzuUmsSjtc', 'object': 'chat.completion', 'created': 1790169655, 'model': 'google/gemma-4-26b-a4b-it:free', 'provider': 'Google AI Studio', 'system_fingerprint': None, 'service_tier': 'default', 'choices': [{'index': 0, 'logprobs': None, 'finish_reason': 'stop', 'native_finish_reason': 'STOP', 'message': {'role': 'assistant', 'content': "There are **3** r's in the word strawberry (st**r**awbe**rr**y).", 'refusal': None, 'reasoning': None}}], 'usage': {'prompt_tokens': 13, 'completion_tokens': 24, 'total_tokens': 37, 'cost': 0, 'is_byok': False, 'prompt_tokens_details': {'cached_tokens': 0, 'cache_write_tokens': 0, 'audio_tokens': 0, 'video_tokens': 0}, 'cost_details': {'upstream_inference_cost': 0, 'upstream_inference_prompt_cost': 0, 'upstream_inference_completions_cost': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'image_tokens': 0, 'audio_tokens': 0}}}
