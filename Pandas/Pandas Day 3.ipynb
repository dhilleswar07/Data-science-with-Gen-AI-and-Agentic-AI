# %%
import pandas as pd

# %%
movies = pd.read_csv(r"E:\DATASCIENCE WITH GEN AI & AGENTIC AI\archive\movie.csv")

# %%
movies.shape
# Out:
# (27278, 3)

# %%
movies.columns
# Out:
# Index(['movieId', 'title', 'genres'], dtype='object')

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
tags = pd.read_csv(r"E:\DATASCIENCE WITH GEN AI & AGENTIC AI\archive\tag.csv")

# %%
tags.shape
# Out:
# (465564, 4)

# %%
tags.columns
# Out:
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='object')

# %%
ratings = pd.read_csv(r"E:\DATASCIENCE WITH GEN AI & AGENTIC AI\archive\rating.csv")

# %%
ratings.shape
# Out:
# (20000263, 4)

# %%
ratings.columns
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
print(movies.columns)
print(tags.columns)
print(ratings.columns)
# Out:
# Index(['movieId', 'title', 'genres'], dtype='object')
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='object')
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
del ratings['timestamp']
del tags['timestamp']

# %%
print(movies.columns)
print(tags.columns)
print(ratings.columns)
# Out:
# Index(['movieId', 'title', 'genres'], dtype='object')
# Index(['userId', 'movieId', 'tag'], dtype='object')
# Index(['userId', 'movieId', 'rating'], dtype='object')
