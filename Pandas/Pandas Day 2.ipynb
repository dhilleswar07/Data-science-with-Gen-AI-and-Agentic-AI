# %%
import pandas as pd

# %%
df = pd.read_excel(r"E:\DATASCIENCE WITH GEN AI & AGENTIC AI\data pandas.xlsx")

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df['IncomeGroup'].unique()
# Out:
# array(['High income', 'Low income', 'Upper middle income',
#        'Lower middle income'], dtype=object)

# %%
df['IncomeGroup'].nunique()
# Out:
# 4

# %%
df[df.IncomeGroup == 'High income']
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0                    Aruba         ABW     10.244          78.90  High income
# 4     United Arab Emirates         ARE     11.044          88.00  High income
# 5                Argentina         ARG     17.716          59.90  High income
# 7      Antigua and Barbuda         ATG     16.447          63.40  High income
# 8                Australia         AUS     13.200          83.00  High income
# ..                     ...         ...        ...            ...          ...
# 174    Trinidad and Tobago         TTO     14.590          63.80  High income
# 180                Uruguay         URY     14.374          57.69  High income
# 181          United States         USA     12.500          84.20  High income
# 184          Venezuela, RB         VEN     19.842          54.90  High income
# 185  Virgin Islands (U.S.)         VIR     10.700          45.30  High income
#
# [67 rows x 5 columns]

# %%
df[df.IncomeGroup == 'Low income']
# Out:
#                   CountryName CountryCode  BirthRate  InternetUsers  \
# 1                 Afghanistan         AFG     35.253           5.90
# 11                    Burundi         BDI     44.151           1.30
# 13                      Benin         BEN     36.440           4.90
# 14               Burkina Faso         BFA     40.551           9.10
# 29   Central African Republic         CAF     34.076           3.50
# 38                    Comoros         COM     34.326           6.50
# 52                    Eritrea         ERI     34.800           0.90
# 55                   Ethiopia         ETH     32.925           1.90
# 64                     Guinea         GIN     37.337           1.60
# 65                Gambia, The         GMB     42.525          14.00
# 66              Guinea-Bissau         GNB     37.503           3.10
# 77                      Haiti         HTI     25.345          10.60
# 93                   Cambodia         KHM     24.462           6.80
# ...

# %%
import matplotlib.pyplot as plt # visualization
import seaborn as sns # distribution visualization

# %matplotlib inline
plt.rcParams['figure.figsize']= 6,4 # rcParams : it decrease the size of the graph 6is width 2 is height

import warnings
warnings.filterwarnings('ignore') # os error

# %%
df['InternetUsers']
# Out:
# 0      78.9
# 1       5.9
# 2      19.1
# 3      57.2
# 4      88.0
#        ...
# 190    20.0
# 191    46.5
# 192     2.2
# 193    15.4
# 194    18.5
# Name: InternetUsers, Length: 195, dtype: float64

# %%
vis1=plt.distplot(df['InternetUsers'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 vis1=plt.distplot(df['InternetUsers'])
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'distplot'

# %%
# .displot =

# %%
vis1=sns.distplot(df['InternetUsers'])

# %% [raw]
#  univarient analysis = plot the graph using 1 variable
#  bivarient analysis = plot the graph using 2 variables

# %%
vis2=sns.displot(df['InternetUsers'])

# %%
vis2=sns.displot(df['InternetUsers'], bins=10)

# %%
is2=sns.displot(df['InternetUsers'], bins=20)

# %%
vis2=sns.distplot(df['InternetUsers'], bins=10)

# %%
vis3 = sns.boxplot( data= df , x = 'IncomeGroup', y = 'BirthRate')

# %%
# outlier is the datapoint which is very far from the observation. it impact the ml algorithm accuracy. thatwhy we introduced probability concept & we connect math to it . outlier are called anomaly detection
# by visualization we can detect outliers.

# %%
vis5 = sns.lmplot( data= df , x = 'InternetUsers' , y = 'BirthRate')

# %%
vis6 = sns.lmplot( data= df , x = 'InternetUsers' , y = 'BirthRate', fit_reg = False)

# %%
vis6 = sns.lmplot( data= df , x = 'InternetUsers' , y = 'BirthRate', fit_reg = False , hue = 'IncomeGroup') # hue is the parameter which helps to detect the color of the graph

# %%
vis7 = sns.lmplot( data= df , x = 'InternetUsers' , y = 'BirthRate', fit_reg = True , hue = 'IncomeGroup')
