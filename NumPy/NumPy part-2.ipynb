# %%
import numpy as np

# %%
m= np.random.randint(1,10,(4,6))
print(m)
# Out:
# [[7 4 2 9 3 3]
#  [9 7 2 4 7 4]
#  [8 4 2 6 2 9]
#  [6 7 6 9 1 1]]

# %%
m[:]
# Out:
# array([[7, 4, 2, 9, 3, 3],
#        [9, 7, 2, 4, 7, 4],
#        [8, 4, 2, 6, 2, 9],
#        [6, 7, 6, 9, 1, 1]], dtype=int32)

# %%
m[:]
# Out:
# array([[7, 4, 2, 9, 3, 3],
#        [9, 7, 2, 4, 7, 4],
#        [8, 4, 2, 6, 2, 9],
#        [6, 7, 6, 9, 1, 1]], dtype=int32)

# %%
m[0]
# Out:
# array([7, 4, 2, 9, 3, 3], dtype=int32)

# %%
m1= np.random.randint(1,10,(9,9))
print(m1)
# Out:
# [[1 2 4 9 8 4 1 9 7]
#  [6 1 9 3 6 3 2 9 2]
#  [4 1 4 2 5 9 6 1 2]
#  [1 2 9 8 7 1 2 2 3]
#  [5 4 4 6 9 7 1 5 6]
#  [5 5 9 4 7 5 2 4 4]
#  [7 7 6 2 7 3 3 6 6]
#  [7 7 7 3 5 1 4 9 1]
#  [9 6 8 8 8 9 4 2 9]]

# %%
m1[0:9:3] # step slicing in array
# Out:
# array([[1, 2, 4, 9, 8, 4, 1, 9, 7],
#        [1, 2, 9, 8, 7, 1, 2, 2, 3],
#        [7, 7, 6, 2, 7, 3, 3, 6, 6]], dtype=int32)

# %%
m1[::2]
# Out:
# array([[1, 2, 4, 9, 8, 4, 1, 9, 7],
#        [4, 1, 4, 2, 5, 9, 6, 1, 2],
#        [5, 4, 4, 6, 9, 7, 1, 5, 6],
#        [7, 7, 6, 2, 7, 3, 3, 6, 6],
#        [9, 6, 8, 8, 8, 9, 4, 2, 9]], dtype=int32)

# %%
m1[::-1] # reversing the array
# Out:
# array([[9, 6, 8, 8, 8, 9, 4, 2, 9],
#        [7, 7, 7, 3, 5, 1, 4, 9, 1],
#        [7, 7, 6, 2, 7, 3, 3, 6, 6],
#        [5, 5, 9, 4, 7, 5, 2, 4, 4],
#        [5, 4, 4, 6, 9, 7, 1, 5, 6],
#        [1, 2, 9, 8, 7, 1, 2, 2, 3],
#        [4, 1, 4, 2, 5, 9, 6, 1, 2],
#        [6, 1, 9, 3, 6, 3, 2, 9, 2],
#        [1, 2, 4, 9, 8, 4, 1, 9, 7]], dtype=int32)

# %%
m1[::-4]
# Out:
# array([[9, 6, 8, 8, 8, 9, 4, 2, 9],
#        [5, 4, 4, 6, 9, 7, 1, 5, 6],
#        [1, 2, 4, 9, 8, 4, 1, 9, 7]], dtype=int32)

# %%
l= [0,1,2,3,4,5]
l
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
arr = np.array(l)
arr
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
arr
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
arr.reshape(2,3)
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %%
arr.reshape(3,2)
# Out:
# array([[0, 1],
#        [2, 3],
#        [4, 5]])

# %%
print(m)
# Out:
# [[7 4 2 9 3 3]
#  [9 7 2 4 7 4]
#  [8 4 2 6 2 9]
#  [6 7 6 9 1 1]]

# %%
m[2,4]
# Out:
# np.int32(2)

# %%
m[2:4]
# Out:
# array([[8, 4, 2, 6, 2, 9],
#        [6, 7, 6, 9, 1, 1]], dtype=int32)

# %%
m
# Out:
# array([[7, 4, 2, 9, 3, 3],
#        [9, 7, 2, 4, 7, 4],
#        [8, 4, 2, 6, 2, 9],
#        [6, 7, 6, 9, 1, 1]], dtype=int32)

# %%
m1
# Out:
# array([[1, 2, 4, 9, 8, 4, 1, 9, 7],
#        [6, 1, 9, 3, 6, 3, 2, 9, 2],
#        [4, 1, 4, 2, 5, 9, 6, 1, 2],
#        [1, 2, 9, 8, 7, 1, 2, 2, 3],
#        [5, 4, 4, 6, 9, 7, 1, 5, 6],
#        [5, 5, 9, 4, 7, 5, 2, 4, 4],
#        [7, 7, 6, 2, 7, 3, 3, 6, 6],
#        [7, 7, 7, 3, 5, 1, 4, 9, 1],
#        [9, 6, 8, 8, 8, 9, 4, 2, 9]], dtype=int32)

# %%
m1[1:4,1:3]
# Out:
# array([[1, 9],
#        [1, 4],
#        [2, 9]], dtype=int32)

# %%
m1[3:8,3:8]
# Out:
# array([[8, 7, 1, 2, 2],
#        [6, 9, 7, 1, 5],
#        [4, 7, 5, 2, 4],
#        [2, 7, 3, 3, 6],
#        [3, 5, 1, 4, 9]], dtype=int32)

# %%
m1.shape
# Out:
# (9, 9)

# %%
id(m1)
# Out:
# 2597560698800

# %%
type(m1)
# Out:
# numpy.ndarray

# %%
m1 < 4
# Out:
# array([[ True,  True, False, False, False, False,  True, False, False],
#        [False,  True, False,  True, False,  True,  True, False,  True],
#        [False,  True, False,  True, False, False, False,  True,  True],
#        [ True,  True, False, False, False,  True,  True,  True,  True],
#        [False, False, False, False, False, False,  True, False, False],
#        [False, False, False, False, False, False,  True, False, False],
#        [False, False, False,  True, False,  True,  True, False, False],
#        [False, False, False,  True, False,  True, False, False,  True],
#        [False, False, False, False, False, False, False,  True, False]])

# %%
m1[m1 < 4]
# Out:
# array([1, 2, 1, 1, 3, 3, 2, 2, 1, 2, 1, 2, 1, 2, 1, 2, 2, 3, 1, 2, 2, 3,
#        3, 3, 1, 1, 2], dtype=int32)

# %%
m1[m1<=4]
# Out:
# array([1, 2, 4, 4, 1, 1, 3, 3, 2, 2, 4, 1, 4, 2, 1, 2, 1, 2, 1, 2, 2, 3,
#        4, 4, 1, 4, 2, 4, 4, 2, 3, 3, 3, 1, 4, 1, 4, 2], dtype=int32)

# %%
m1[m1!=5]
# Out:
# array([1, 2, 4, 9, 8, 4, 1, 9, 7, 6, 1, 9, 3, 6, 3, 2, 9, 2, 4, 1, 4, 2,
#        9, 6, 1, 2, 1, 2, 9, 8, 7, 1, 2, 2, 3, 4, 4, 6, 9, 7, 1, 6, 9, 4,
#        7, 2, 4, 4, 7, 7, 6, 2, 7, 3, 3, 6, 6, 7, 7, 7, 3, 1, 4, 9, 1, 9,
#        6, 8, 8, 8, 9, 4, 2, 9], dtype=int32)

# %%
m1[m1==5]
# Out:
# array([5, 5, 5, 5, 5, 5, 5], dtype=int32)

# %%
m1[m1>=5]
# Out:
# array([9, 8, 9, 7, 6, 9, 6, 9, 5, 9, 6, 9, 8, 7, 5, 6, 9, 7, 5, 6, 5, 5,
#        9, 7, 5, 7, 7, 6, 7, 6, 6, 7, 7, 7, 5, 9, 9, 6, 8, 8, 8, 9, 9],
#       dtype=int32)

# %% [markdown]
# # Image analysis using np , PIL

# %%
import matplotlib.pyplot as plt

# %%
from PIL import Image # python imageing library

# %%
from PIL import Image

# %%
feature_image = Image.open(r"C:\Users\Dhilleswar\OneDrive\Pictures\Saved Pictures\IMG-20241217-WA0035.jpg")
feature_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x1280>

# %%
print(type(feature_image))
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>

# %%
fea_arr = np.asarray(feature_image)
fea_arr
# Out:
# array([[[133, 139, 105],
#         [135, 141, 107],
#         [138, 142, 109],
#         ...,
#         [136, 162,  71],
#         [136, 163,  70],
#         [136, 163,  70]],
#
#        [[135, 139, 106],
#         [137, 141, 108],
#         [139, 143, 110],
#         ...,
#         [135, 161,  70],
#         [136, 162,  71],
#         [136, 162,  71]],
#
#        [[137, 140, 109],
#         [138, 141, 110],
#         [141, 144, 113],
#         ...,
#         [134, 160,  69],
#         [134, 160,  69],
#         [135, 161,  70]],
#
#        ...,
#
#        [[232, 123,  94],
#         [232, 123,  92],
#         [233, 122,  92],
#         ...,
#         [203, 181, 105],
#         [203, 181, 106],
#         [203, 181, 106]],
#
#        [[232, 123,  94],
#         [233, 122,  92],
#         [233, 122,  92],
#         ...,
#         [203, 181, 105],
#         [203, 181, 105],
#         [203, 181, 106]],
#
#        [[233, 122,  94],
#         [233, 122,  92],
#         [233, 122,  92],
# ...

# %%
plt.imshow(fea_arr)
plt.show()

# %%
fea_arr.shape
# Out:
# (1280, 1280, 3)
