# %% [markdown]
# # Advanced Python

# %% [raw]
# if
# else
# if else
# nested of
# if elif else

# %%
#1- check the number is even number or not 

x = 4
r = x % 2 

if r == 0:
    print('Even number')
# Out:
# Even number

# %%
#1- check the number is even number or not 
x = 4
r = x % 2 

if r == 0:
print('Even number')
# Out:
#   Cell In[3], line 6
#     print('Even number')
#     ^
# IndentationError: expected an indented block after 'if' statement on line 5

# %%
x = 4
r = x % 2 

if r == 0:
 print('Even number')
# Out:
# Even number

# %%
x = 5
r = x % 2 

if r == 0:
    print('Even number')

# %%
x = 5
r = x % 2 

if r == 0:
    print('Even number') 
    
print('Odd Number')
# Out:
# Odd Number

# %%
x = 8
r = x % 2 

if r == 0:
    print('Even number') 
    
print('Odd Number')
# Out:
# Even number
# Odd Number

# %%
x = 9
r = x % 2 

if r == 0:
    print('Even number') 

if r != 0 :
    print('Odd number')
# Out:
# Odd number

# %%
x = 8
r = x % 2 

if r == 0:
    print('Even number') 

if r == 1 :
    print('Odd number')
# Out:
# Even number

# %%
x = 8
r = x % 2 

if r == 0:
    print('Even number') 

else:
    print('Odd number')
# Out:
# Even number

# %%
# nested if 

x = 3
r = x % 2

if r == 0:
    print('Even number')
    
    if x>5:
        print('greater number')
  
else:
    print('Odd Number')
# Out:
# Odd Number

# %%
# nested if 
x = 4
r = x % 2

if r == 0:
    print('Even number')
    
    if x>5:
        print('greater number')
  
else:
    print('Odd Number')
# Out:
# Even number

# %%
# nested if 
x = 4
r = x % 2

if r == 0:
    print('Even number')
    
    if x>5:
        print('greater number')
    else:
        print('lesser number')
  
else:
    print('Odd Number')
# Out:
# Even number
# lesser number

# %%
x = 1

if x == 1:
    print('one')
if x == 2:
    print('Two')
if x == 3:
    print('Three')
if x == 4:
    print('four')
# Out:
# one

# %%
x = 10

if x == 1:
    print('one')

elif x == 2:
    print('Two')
elif x == 3:
    print('Three')
elif x == 4:
    print('four')

# %%
x = 10

if x == 1:
    print('one')

elif x == 2:
    print('Two')
elif x == 3:
    print('Three')
elif x == 4:
    print('four')

else:
    print('number not found')
# Out:
# number not found

# %% [markdown]
# # Loops

# %%
i = 1         # initializing
while i<=5:    # condition
    print('data science')
    i = i + 1  # increment
# Out:
# data science
# data science
# data science
# data science
# data science

# %%
i = 1         # initializing
while i<=5:    # condition
    print('data science : ', i)
    i = i + 1  # increment
# Out:
# data science :  1
# data science :  2
# data science :  3
# data science :  4
# data science :  5

# %%
i = 5         # initializing
while i>=1:    # condition
    print('data science : ', i)
    i = i - 1  # increment
# Out:
# data science :  5
# data science :  4
# data science :  3
# data science :  2
# data science :  1

# %%
i = 5         # initializing
while i>1:    # condition
    print('data science : ', i)
    i = i - 1  # increment
# Out:
# data science :  5
# data science :  4
# data science :  3
# data science :  2

# %%
i = 1

while i<=5:
    print('data science') # when we mention end then new line will not create
    j = 1
    while j<=4:
        print('technology')
        j = j + 1
        
    i = i + 1
    print()
    
    # the output which we got is very lengty but how to make them one line lets refer to below code
# Out:
# data science
# technology
# technology
# technology
# technology
#
# data science
# technology
# technology
# technology
# technology
#
# data science
# technology
# technology
# technology
# technology
#
# data science
# technology
# technology
# technology
# technology
#
# data science
# technology
# technology
# technology
# technology
