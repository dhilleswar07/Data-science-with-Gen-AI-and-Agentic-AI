# %%
import cv2

# %%
import numpy as np

# %%
input = cv2.imread(r"C:\Users\Dhilleswar\OneDrive\Pictures\Saved Pictures\WhatsApp Image 2026-07-23 at 12.21.41 PM.jpeg")

# %%
input
# Out:
# array([[[89, 80, 76],
#         [90, 81, 77],
#         [90, 81, 77],
#         ...,
#         [69, 64, 63],
#         [69, 64, 63],
#         [69, 64, 63]],
#
#        [[89, 80, 76],
#         [90, 81, 77],
#         [90, 81, 77],
#         ...,
#         [69, 64, 63],
#         [69, 64, 63],
#         [69, 64, 63]],
#
#        [[89, 80, 76],
#         [90, 81, 77],
#         [90, 81, 77],
#         ...,
#         [69, 64, 63],
#         [69, 64, 63],
#         [69, 64, 63]],
#
#        ...,
#
#        [[76, 66, 59],
#         [76, 66, 59],
#         [76, 66, 59],
#         ...,
#         [72, 62, 55],
#         [72, 62, 55],
#         [72, 62, 55]],
#
#        [[76, 66, 59],
#         [76, 66, 59],
#         [76, 66, 59],
#         ...,
#         [72, 62, 55],
#         [72, 62, 55],
#         [72, 62, 55]],
#
#        [[77, 67, 60],
#         [77, 67, 60],
#         [77, 67, 60],
#         ...,
#         [72, 62, 55],
#         [72, 62, 55],
#         [72, 62, 55]]], shape=(1254, 1254, 3), dtype=uint8)

# %%
cv2.imshow("Elephant", input)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
print('height of image:', int(input.shape[0]),'pixels')
print('width of image:', int(input.shape[1]),'pixels')
# Out:
# height of image: 1254 pixels
# width of image: 1254 pixels

# %%
cv2.imwrite('output.png', input)
# Out:
# True

# %%
import os
os.getcwd()
# Out:
# 'e:\\DATASCIENCE WITH GEN AI & AGENTIC AI\\VSCODE\\OpenCV'
