# %% [markdown]
# # TYPE CASTING

# %% [raw]
# Type casting is nothing but changing one datatype to another datatype is called type casting

# %% [markdown]
# # Test case 1

# %% [raw]
# Changing all other datatypes to int datatype

# %%
int (3)
# Out:
# 3

# %%
int(5.7)
# Out:
# 5

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
int(2+5j) # changing datatype from complex to int is not possible
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 int(2+5j) # changing datatype from complex to int is not possible
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int('13')
# Out:
# 13

# %%
int ('5.7') #changing datatype from float string to int is not possible
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 int ('5.7') #changing datatype from float string to int is not possible
#
# ValueError: invalid literal for int() with base 10: '5.7'

# %%
int ( 'dhilleswar') # changing  datatype from test string to int is not possible
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 int ( 'dhilleswar') # changing  datatype from test string to int is not possible
#
# ValueError: invalid literal for int() with base 10: 'dhilleswar'

# %%
int ( 23.6,53.6) # we cannot pass more than one argument in the typecasting
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 int ( 23.6,53.6) # we cannot pass more than one argument in the typecasting
#
# TypeError: 'float' object cannot be interpreted as an integer

# %% [markdown]
# # Test case 2

# %% [raw]
# changing all other datatype to float datatype

# %%
float(7)
# Out:
# 7.0

# %%
float(7.2)
# Out:
# 7.2

# %%
float(2+5j) # changing datatype from complex to float is not possible
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 float(2+5j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
float('3')
# Out:
# 3.0

# %%
float('5.3')
# Out:
# 5.3

# %%
float("3")
# Out:
# 3.0

# %%
float('2.3','5.6')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 float('2.3','5.6')
#
# TypeError: float expected at most 1 argument, got 2

# %%
float(2.3,5.6)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 float(2.3,5.6)
#
# TypeError: float expected at most 1 argument, got 2

# %%
float('2.3,5.6')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 float('2.3,5.6')
#
# ValueError: could not convert string to float: '2.3,5.6'

# %%
float('2,3')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 float('2,3')
#
# ValueError: could not convert string to float: '2,3'

# %% [markdown]
# # Test case 3

# %% [raw]
# changing all other datatypes to boolean datatype

# %%
bool(1)
# Out:
# True

# %%
bool(1.2)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(2+5j)
# Out:
# True

# %%
bool('dhill')
# Out:
# True

# %%
bool('qwer','djrk')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 bool('qwer','djrk')
#
# TypeError: bool expected at most 1 argument, got 2

# %%
bool(567,5784)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 bool(567,5784)
#
# TypeError: bool expected at most 1 argument, got 2

# %% [markdown]
# # Test case 4

# %% [raw]
# changing all other datatypes to complex datatype

# %%
complex(1)
# Out:
# (1+0j)

# %%
complex(1,7)
# Out:
# (1+7j)

# %%
complex(1.023,2.35)
# Out:
# (1.023+2.35j)

# %%
complex('dhill')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 complex('dhill')
#
# ValueError: complex() arg is a malformed string

# %%
complex('7')
# Out:
# (7+0j)

# %%
complex('2','7')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 complex('2','7')
#
# TypeError: complex() can't take second arg if first is a string

# %% [markdown]
# # Test case 5

# %% [raw]
# changing all other datatypes to string datatype

# %%
str(1)
# Out:
# '1'

# %%
str('7')
# Out:
# '7'

# %%
str(1.2)
# Out:
# '1.2'

# %%
str('2.365')
# Out:
# '2.365'

# %%
str(True)
# Out:
# 'True'

# %%
str(2+6j)
# Out:
# '(2+6j)'

# %%
str(2,6)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 str(2,6)
#
# TypeError: str() argument 'encoding' must be str, not int

# %%
str('6','7')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 str('6','7')
#
# TypeError: decoding str is not supported

# %% [markdown]
# # OPERATORS

# %% [raw]
# Operator are 5 types
#  1 Arithmetic operator
#  2 Assignment operator
#  3 Relational operator
#  4 Logical operator
#  5 Unary operator

# %% [markdown]
# # Arthimetic operator

# %%
a=5
b=7

# %%
print(a)
print(b)
# Out:
# 5
# 7

# %%
print ( a+b ) # add 
print ( a-b ) # sub
print ( a*b ) # multiply
print ( a**b ) # a power b
print ( a/b ) # float division
print ( a//b ) # int division
print ( a%b ) # modulus(remainder)
# Out:
# 12
# -2
# 35
# 78125
# 0.7142857142857143
# 0
# 5

# %% [markdown]
# # Assignment operator

# %%
a = 4
a
# Out:
# 4

# %%
a = 5

# %%
a +=2
a
# Out:
# 9

# %%
a -= 5
a
# Out:
# -1

# %%
a *= 5
a
# Out:
# -5

# %%
a /= 5
a
# Out:
# -1.0

# %%
a //= 5
a
# Out:
# -1.0

# %% [markdown]
# # Relational operator

# %%
a = 5
b = 10

# %%
a > b
# Out:
# False

# %%
a < b
# Out:
# True

# %%
print (a >= b)
print (a <= b)
print (a == b)
print (a != b)
# Out:
# False
# True
# False
# True

# %% [markdown]
# # logical operator

# %%
a = 5
b = 7

# %%
a < 8 and  b < 2
# Out:
# False

# %%
a > 8 and b > 2
# Out:
# False

# %%
a<8 and b>2
# Out:
# True

# %%
a < 8 or  b < 2
# Out:
# True

# %%
a > 8 or b > 2
# Out:
# True

# %%
a<8 or b>2
# Out:
# True

# %%
a > 8 or b < 2
# Out:
# False

# %% [markdown]
# # Unary operator

# %%
a = 7
a
# Out:
# 7

# %%
b = -a
b
# Out:
# -7
