# %% [markdown]
# VARIABLES

# %% [raw]
# Variables is case sensitive
# Variable doesn't with digit but ends with digit
# Variable doesn't support any special characters . except underscroll _

# %%
import sys 
import keyword 
import operator 
from datetime import datetime 
import os

# %% [markdown]
# KEYWORDS

# %% [markdown]
# keywords are the reserved words in python and can't be used as identifier

# %%
print (keyword.kwlist) # List all Python Keywords
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
len(keyword.kwlist) # Python contains 35 keywords
# Out:
# 35

# %% [markdown]
# IDENTIFIER'S

# %% [markdown]
# An identifier is a name given to entities like class, functions, variables, etc. It helps to differentiate
# one entity from another.

# %%
val5 = 7

# %%
val_ = 77

# %% [markdown]
# COMMENTS IN PYTHON

# %% [markdown]
# Comments can be used to explain the code for more readability

# %%
#single line comment
val5 = 7

# %%
#multi
#line 
#comment

# %% [markdown]
# PYTHON DATA TYPES

# %% [raw]
# int
# float
# boolean
# complex
# string

# %%
i = 7 #int datatype
i
# Out:
# 7

# %%
type(i)
# Out:
# int

# %%
f=7.27 #float datatype
f
# Out:
# 7.27

# %%
type(f)
# Out:
# float

# %% [raw]
# in float we use e (exponential)

# %%
7e0 #exponential
# Out:
# 7.0

# %%
7e1
# Out:
# 70.0

# %%
True#boolean datatype
# Out:
# True

# %%
False
# Out:
# False

# %%
a=True
b=False

# %%
print(a+b)
print(a-b)
print(a*b)
print(b/a)
# Out:
# 1
# 1
# 0
# 0.0

# %%
type(a)
# Out:
# bool

# %% [raw]
# complex datatype
#
# a+bj
#
# a=real part
# b=imaginary part
# j=square root of -1

# %%
a = 2+7j #complex datatype
a
# Out:
# (2+7j)

# %%
type(a)
# Out:
# complex

# %%
a.real
# Out:
# 2.0

# %%
a.imag
# Out:
# 7.0

# %% [raw]
# string
#
# string are always start and ends with quotes '', "" , ''' '''

# %%
d = 'dhilleswar' #string datatype
d
# Out:
# 'dhilleswar'

# %%
len(d)
# Out:
# 10

# %%
id(d)
# Out:
# 1960014997424

# %%
d[5]
# Out:
# 'e'

# %%
d[-2]
# Out:
# 'a'

# %% [raw]
# PYTHON INDEXING
#
# 1 forward indexing ( left to right)
# 2 backward indexing ( right to left )

# %% [markdown]
# slicing

# %%
d = 'Dhilleswar'

# %%
d[:]
# Out:
# 'Dhilleswar'

# %%
d[5:] #forward slicing
# Out:
# 'eswar'

# %%
d[7:]
# Out:
# 'war'

# %%
d[:5]
# Out:
# 'Dhill'

# %%
d[-1000:10]
# Out:
# 'Dhilleswar'

# %%
d[-7:-3] #backward slicing
# Out:
# 'lles'

# %%
d[-5:-1]
# Out:
# 'eswa'
