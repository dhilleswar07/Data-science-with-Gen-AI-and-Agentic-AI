# %% [markdown]
# # TUPLE ()

# %% [raw]
# tuple is an inmutable ordered collection of elements
#  - tuples are similar to lists ,but unlike list they cannot be changed after their creation
#  - can hold elements of different datatypes
#  - these are ordered , heterogenous and inmutable

# %%
t=() # creating a tuple
t
# Out:
# ()

# %%
t=(3,5,7,8) # creating tuple using integer
t
# Out:
# (3, 5, 7, 8)

# %%
t=(3,3.5,'dhilleswar',True,(4+9j))
t
# Out:
# (3, 3.5, 'dhilleswar', True, (4+9j))

# %%
t[4] # indexing
# Out:
# (4+9j)

# %%
l=[3,3.5,'dhilleswar',True,(4+9j)]
l1=tuple(l)
l1
# Out:
# (3, 3.5, 'dhilleswar', True, (4+9j))

# %%
type(l1)
# Out:
# tuple

# %%
t=(3,3.5,'dhilleswar',True,(4+9j))
t
# Out:
# (3, 3.5, 'dhilleswar', True, (4+9j))

# %%
t.count(3)
# Out:
# 1

# %%
t.index(3.5)
# Out:
# 1

# %%
t.index(True)
# Out:
# 3

# %% [markdown]
# # SET {}

# %% [raw]
# set & dictionary both are assigned with { }
# {} empty curly braces automatically understand it as a dictionary
# {1,2,3} consider it as a set
# in set duplicates are not allowed
#
# If user assign similar datatype it will print output as ordered items
# In set indexing and slicing is not allowed
# In set pop() by default work and remove random num in the set
#  * set.pop() : it remove random num from the set
#  * set.pop(4) : it shows error because in set index is not allowed

# %%
S= {}
S
# Out:
# {}

# %%
type(S)
# Out:
# dict

# %%
s={1,2,3,4}
s
# Out:
# {1, 2, 3, 4}

# %%
type(s)
# Out:
# set

# %%
s.add(2.5)
s
# Out:
# {1, 2, 2.5, 3, 4}

# %%
s1=s.copy()
s1
# Out:
# {1, 2, 2.5, 3, 4}

# %%
s1.clear()
s1
# Out:
# set()

# %%
print(s)
print(s1)
# Out:
# {1, 2.5, 2, 3, 4}
# set()

# %%
s={3,3.5,34,567,424,75,23,'dhilleswar',True,(4+9j)}
s
# Out:
# {(4+9j), 23, 3, 3.5, 34, 424, 567, 75, True, 'dhilleswar'}

# %%
s.pop()
s
# Out:
# {(4+9j), 23, 3, 3.5, 34, 424, 567, 75, 'dhilleswar'}

# %%
s
# Out:
# {(4+9j), 23, 3, 3.5, 34, 424, 567, 75, 'dhilleswar'}

# %%
s.pop(2)
s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 s.pop(2)
#       2 s
#
# TypeError: set.pop() takes no arguments (1 given)

# %%
s.discard(50)

# %%
s.discard(0)
s
# Out:
# {(4+9j), 23, 3, 3.5, 34, 424, 567, 75, 'dhilleswar'}

# %%
s.discard(3)
s
