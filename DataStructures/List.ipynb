# %% [markdown]
# # DATA STRUCTURES

# %% [markdown]
# -  list
# -  tuple
# -  set
# -  dict
# -  range

# %% [markdown]
# # list

# %%
l = []
l
# Out:
# []

# %%
len(l1)
# Out:
# 0

# %%
l1 = [30,40,70,50]
l1
# Out:
# [30, 40, 70, 50]

# %%
l1.append(20)
l1.append(10)
l1.append(70)

# %%
l1
# Out:
# [30, 40, 70, 50, 20, 10, 70]

# %%
len(l1)
# Out:
# 7

# %%
l1.append(['vijay','eswar'])

# %%
 l1
# Out:
# [30, 40, 70, 50, 20, 10, 70, ['vijay', 'eswar']]

# %%
len(l1)
# Out:
# 8

# %%
l = [4,5,6]
l1 = [3,4,5]
l2 = [9,0,8]

# %%
print(id(l))
print(id(l1))
print(id(l2))
# Out:
# 2758113188928
# 2758113188864
# 2758113161792

# %%
l1
# Out:
# [3, 4, 5]

# %%
l1 = [ 20, 40, 60, 70, 90, [ 'abc', 'dek' ,'ghi' ]]
l1
# Out:
# [20, 40, 60, 70, 90, ['abc', 'dek', 'ghi']]

# %%
90 in l1
# Out:
# True

# %%
[ 'abc', 'dek' ,'ghi' ] in l1
# Out:
# True

# %%
10 in l1
# Out:
# False

# %%
l4 = l1.copy()

# %%
l4
# Out:
# [20, 40, 60, 70, 90, ['abc', 'dek', 'ghi']]

# %%
print(id(l1))
print(id(l4))
# Out:
# 2758113184832
# 2758112934080

# %%
l1.count(90)
# Out:
# 1

# %%
l1.clear()

# %%
l1
# Out:
# []

# %%
l1 = [20, 40, 60, 70, 90, 20, ['abc', 'dek', 'ghi']]
l1
# Out:
# [20, 40, 60, 70, 90, 20, ['abc', 'dek', 'ghi']]

# %%
l1.extend([50])
l1
# Out:
# [20, 40, 60, 70, 90, 20, ['abc', 'dek', 'ghi'], 50]

# %%
l1.index(70)
# Out:
# 3

# %%
l1.insert(1,10)
l1
# Out:
# [20, 10, 40, 60, 70, 90, 20, ['abc', 'dek', 'ghi'], 50]

# %%
l1.pop()
l1
# Out:
# [20, 10, 40, 60, 70, 90, 20, ['abc', 'dek', 'ghi']]

# %%
l1.pop(7)
l1
# Out:
# [20, 10, 40, 60, 70, 90, 20]

# %%
l1.remove(20)
l1
# Out:
# [10, 40, 60, 70, 90, 20]

# %%
l1.reverse()
l1
# Out:
# [20, 90, 70, 60, 40, 10]

# %%
l1.sort()
l1
# Out:
# [10, 20, 40, 60, 70, 90]
